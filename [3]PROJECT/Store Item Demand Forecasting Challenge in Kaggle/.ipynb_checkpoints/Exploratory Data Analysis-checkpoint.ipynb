# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from datetime import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# %%
data.head()
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
data.plot(figsize=(19,9))

# %% [markdown]
# ## Seasonal Patterns in Time series data

# %% [markdown]
# ### for removing trend, use 'differencing'

# %%
sales = data[['sales']]
sales.diff().plot(figsize=(20,10))

# %% [markdown]
# ## Correlation

# %%
data.corr()
# Out:
#          store      item     sales
# store  1.00000  0.000000 -0.008170
# item   0.00000  1.000000 -0.055998
# sales -0.00817 -0.055998  1.000000

# %% [markdown]
# ### After removing trend

# %%
data.diff().plot(figsize=(20,10))

# %%
data.diff().corr()
# Out:
#           store      item     sales
# store  1.000000 -0.947743  0.003198
# item  -0.947743  1.000000 -0.016361
# sales  0.003198 -0.016361  1.000000

# %% [markdown]
# #### There is strong negative correlation with item
