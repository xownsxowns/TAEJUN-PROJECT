# %%
import matplotlib.pyplot as plt

# %%
x = [0.4000, -0.9000, 1.6000, 0.0000, -0.7000, -0.9000, 1.7000, -1.2000, 1.6000, -0.7000]
y = [-0.2, 0.1, 0.8, 1, 0.9, 0.2, 0.5, -0.9, 1, 1]

# %%
x, y
# Out:
# ([0.4, -0.9, 1.6, 0.0, -0.7, -0.9, 1.7, -1.2, 1.6, -0.7],
#  [-0.2, 0.1, 0.8, 1, 0.9, 0.2, 0.5, -0.9, 1, 1])

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Classic-Modern')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [-0.3000, -0.4000, 1.7000, -1.1000, 1.4000, 0.6000, 1.4000, -1.6000, 1.4000, -0.1000]
y = [-0.5000, -1.1000, 2.1000, -1.9000, -0.6000, -0.4000, 0.6000, -1.7000, 1.8000, -0.8000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Sophisticated-Countrified')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [0.6000, 1.0000, -2.6000, 0.0000, -0.6000, 0.3000, -2.0000, 1.5000, -2.4000, 0.6000]
y = [0.1000, 1.9000, -2.5000, 0.0000, -0.2000, 0.2000, -1.8000, 1.4000, -2.3000, -0.5000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Casual-luxurious')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [-1.0000, -1.2000, 2.6000, -0.1000, -0.6000, -0.7000, 2.1000, -2.1000, 2.7000, -1.3000]
y = [-1.1000, -1.4000, 2.5000, 0.1000, -1.1000, -0.4000, 2.1000, -1.4000, 2.4000, 0.4000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Calm-Cheerful')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [1.6000, 1.7000, -0.9000, 1.5000, 0.3000, 1.0000, -1.1000, 1.9000, -1.4000, 1.2000]
y = [1.8000, 2.0000, -1.4000, 1.6000, 0.9000, 1.5000, -0.5000, 2.2000, -1.7000, 0.2000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Not neat-Neat')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [-0.4000, 0.1000, 2.1000, 0.5000, -1.0000, -0.1000, 2.1000, -0.8000, 2.6000, 0.4000]
y = [-0.6000, 0.2000, 2.5000, 0.1000, -0.4000, -0.8000, 2.3000, -0.7000, 2.6000, 1.3000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Stately-Not stately')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [-0.1000, -0.1000, 0.0000, -0.5000, 1.0000, 1.3000, -1.6000, 0.7000, 0.8000, 1.7000]
y = [0.2000, -1.1000, 0.6000, -0.1000, 1.6000, 1.8000, -1.9000, 0.4000, 0.9000, 0.9000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Cold-Warm')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [0.0000, -0.2000, -0.4000, -0.9000, -0.2000, -1.2000, 0.3000, -0.5000, 0.8000, -1.4000]
y = [-0.7000, 0.0000, 0.2000, -1.1000, -0.4000, -1.3000, 0.6000, -1.2000, 0.4000, -1.2000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Soft-Tough')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [0.5000, 0.7000, -2.0000, 1.1000, 0.1000, 0.5000, -1.6000, 1.7000, -1.9000, 1.2000]
y = [1.5000, 1.6000, -2.1000, 0.9000, 0.9000, 1.1000, -0.3000, 1.8000, -1.5000, 0.3000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Not intellectual-Intellectual')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()

# %%
x = [-0.1000, -0.1000, -1.6000, 0.9000, 0.2000, 0.2000, -1.1000, 0.5000, -1.2000, 0.4000]
y = [0.1000, -0.4000, -0.5000, 0.6000, 0.3000, 0.7000, -0.7000, 0.9000, -0.6000, 0.2000]

# %%
plt.plot(x,y,'ro')
plt.axis([-3,3,-3,3])
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3],'b--')
plt.title('Discomfortable-Comfortable')
plt.xlabel('Male')
plt.ylabel('Female')

# %%
plt.show()
