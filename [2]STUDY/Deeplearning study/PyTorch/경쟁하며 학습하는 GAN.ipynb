# %% [markdown]
# ### 9.2 GAN으로 새로운 패션 아이템 생성하기

# %% [markdown]
# #### 9.2.1 학습 준비

# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torchvision.utils import save_image
import matplotlib.pyplot as plt
import numpy as np

# %%
# 하이퍼파라미터
EPOCHS = 500
BATCH_SIZE = 100
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print("다음 장치를 사용합니다:", DEVICE)

# Fashion MNIST 데이터셋
trainset = datasets.FashionMNIST('./ .data',
                                train=True,
                                download=True,
                                transform=transforms.Compose([
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5,), (0.5,))
                                ]))
train_loader = torch.utils.data.DataLoader(
dataset = trainset,
batch_size = BATCH_SIZE,
shuffle = True)
# Out:
# 다음 장치를 사용합니다: cpu

# %% [markdown]
# #### 9.2.2 생성자와 판별자 구현

# %%
# 생성자 (Generator)
G = nn.Sequential(
    nn.Linear(64, 256),
    nn.ReLU(),
    nn.Linear(256, 256),
    nn.ReLU(),
    nn.Linear(256, 784),
    nn.Tanh())

# %%
# 판별자 (Discriminator), Leaky ReLU 활성화 함수를 사용
D = nn.Sequential(
    nn.Linear(784, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 1),
    nn.Sigmoid())

# %% [markdown]
# #### 9.2.3 GAN 학습 구현

# %%
# 모델의 가중치를 지정한 장치로 보내기
D = D.to(DEVICE)
G = G.to(DEVICE)

# 이진 교차 엔트로피 오차 함수와 생상자와 판별자를 최적화할 Adam 모듈
criterion = nn.BCELoss()
d_optimizer = optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = optim.Adam(G.parameters(), lr=0.0002)

# %%
total_step = len(train_loader)
for epoch in range(EPOCHS):
    for i, (images, _) in enumerate(train_loader):
        images = images.reshape(BATCH_SIZE, -1).to(DEVICE)
        
        # '진짜'와 '가짜' 레이블 생성
        real_labels = torch.ones(BATCH_SIZE, 1).to(DEVICE)
        fake_labels = torch.zeros(BATCH_SIZE, 1).to(DEVICE)
        
        # 판별자가 진짜 이미지를 진짜로 인식하는 오차 계산
        outputs = D(images)
        d_loss_real = criterion(outputs, real_labels)
        real_score = outputs
        
        # 무작위 텐서로 가짜 이미지 생성
        z = torch.randn(BATCH_SIZE, 64).to(DEVICE)
        fake_images = G(z)
        
        # 판별자가 가짜 이미지를 가짜로 인식하는 오차 계산
        outputs = D(fake_images)
        d_loss_fake = criterion(outputs, fake_labels)
        fake_score = outputs
        
        # 진짜와 가짜 이미지를 갖고 낸 오차를 더해서 판별자의 오차 계산
        d_loss = d_loss_real + d_loss_fake
        
        # 역전파 알고리즘으로 판별자 모델의 학습을 진행
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()
        
        # 생성자가 판별자를 속였는지에 대한 오차 계산
        fake_images = G(z)
        outputs = D(fake_images)
        g_loss = criterion(outputs, real_labels)
        
        # 역전파 알고리즘으로 생성자 모델의 학습을 진행
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        
        g_loss.backward()
        g_optimizer.step()
        
    # 학습 진행 알아보기
    print('이폭 [{}/{}] d_loss:{:.4f} g_loss: {:.4f} D(x):{:.2f} D(G(z)):{:.2f}'.format(epoch, EPOCHS, d_loss.item(), g_loss.item(),
                                                                                         real_score.mean().item(), fake_score.mean().item()))
# Out:
# 이폭 [0/500] d_loss:0.0316 g_loss: 4.8547 D(x):0.99 D(G(z)):0.02
# 이폭 [1/500] d_loss:0.0350 g_loss: 5.9017 D(x):0.98 D(G(z)):0.01
# 이폭 [2/500] d_loss:0.1488 g_loss: 5.9621 D(x):0.95 D(G(z)):0.01
# 이폭 [3/500] d_loss:0.0323 g_loss: 5.5764 D(x):0.99 D(G(z)):0.02
# 이폭 [4/500] d_loss:0.2885 g_loss: 4.3164 D(x):0.96 D(G(z)):0.16
# 이폭 [5/500] d_loss:0.0823 g_loss: 4.8647 D(x):0.98 D(G(z)):0.04
# 이폭 [6/500] d_loss:0.1455 g_loss: 5.5897 D(x):0.97 D(G(z)):0.04
# 이폭 [7/500] d_loss:0.0920 g_loss: 5.7491 D(x):0.96 D(G(z)):0.03
# 이폭 [8/500] d_loss:0.0909 g_loss: 5.2170 D(x):0.96 D(G(z)):0.03
# 이폭 [9/500] d_loss:0.2652 g_loss: 4.8708 D(x):0.95 D(G(z)):0.08
# 이폭 [10/500] d_loss:0.4806 g_loss: 3.8155 D(x):0.85 D(G(z)):0.07
# 이폭 [11/500] d_loss:0.0956 g_loss: 4.8042 D(x):0.96 D(G(z)):0.04
# 이폭 [12/500] d_loss:0.3136 g_loss: 4.1125 D(x):0.93 D(G(z)):0.10
# 이폭 [13/500] d_loss:0.3067 g_loss: 4.1211 D(x):0.95 D(G(z)):0.15
# 이폭 [14/500] d_loss:0.2445 g_loss: 3.5715 D(x):0.95 D(G(z)):0.13
# 이폭 [15/500] d_loss:0.1903 g_loss: 3.3733 D(x):0.94 D(G(z)):0.09
# 이폭 [16/500] d_loss:0.2473 g_loss: 4.0175 D(x):0.94 D(G(z)):0.11
# 이폭 [17/500] d_loss:0.4479 g_loss: 4.2720 D(x):0.85 D(G(z)):0.04
# 이폭 [18/500] d_loss:0.5180 g_loss: 2.5730 D(x):0.90 D(G(z)):0.23
# 이폭 [19/500] d_loss:0.2397 g_loss: 3.4827 D(x):0.94 D(G(z)):0.11
# 이폭 [20/500] d_loss:0.3408 g_loss: 3.2995 D(x):0.91 D(G(z)):0.09
# 이폭 [21/500] d_loss:0.4126 g_loss: 3.3863 D(x):0.92 D(G(z)):0.17
# 이폭 [22/500] d_loss:0.3684 g_loss: 3.4602 D(x):0.90 D(G(z)):0.15
# 이폭 [23/500] d_loss:0.4608 g_loss: 3.1300 D(x):0.87 D(G(z)):0.13
# 이폭 [24/500] d_loss:0.8085 g_loss: 2.4188 D(x):0.74 D(G(z)):0.15
# 이폭 [25/500] d_loss:0.4116 g_loss: 2.8622 D(x):0.87 D(G(z)):0.10
# 이폭 [26/500] d_loss:0.3317 g_loss: 3.3382 D(x):0.89 D(G(z)):0.09
# 이폭 [27/500] d_loss:0.4449 g_loss: 2.9103 D(x):0.87 D(G(z)):0.15
# 이폭 [28/500] d_loss:0.4079 g_loss: 3.3066 D(x):0.91 D(G(z)):0.18
# 이폭 [29/500] d_loss:0.4342 g_loss: 2.7701 D(x):0.90 D(G(z)):0.16
# 이폭 [30/500] d_loss:0.5180 g_loss: 3.7342 D(x):0.81 D(G(z)):0.10
# 이폭 [31/500] d_loss:0.7022 g_loss: 2.7688 D(x):0.83 D(G(z)):0.21
# 이폭 [32/500] d_loss:0.4705 g_loss: 3.3432 D(x):0.83 D(G(z)):0.12
# 이폭 [33/500] d_loss:0.7401 g_loss: 2.9593 D(x):0.81 D(G(z)):0.16
# 이폭 [34/500] d_loss:0.4530 g_loss: 3.1275 D(x):0.82 D(G(z)):0.09
# 이폭 [35/500] d_loss:0.6060 g_loss: 4.3733 D(x):0.82 D(G(z)):0.10
# 이폭 [36/500] d_loss:0.5369 g_loss: 2.8037 D(x):0.85 D(G(z)):0.19
# 이폭 [37/500] d_loss:0.5170 g_loss: 2.7010 D(x):0.85 D(G(z)):0.20
# 이폭 [38/500] d_loss:0.4180 g_loss: 3.3237 D(x):0.89 D(G(z)):0.16
# 이폭 [39/500] d_loss:0.9182 g_loss: 2.9049 D(x):0.72 D(G(z)):0.14
# 이폭 [40/500] d_loss:0.5813 g_loss: 3.5910 D(x):0.77 D(G(z)):0.09
# 이폭 [41/500] d_loss:0.7934 g_loss: 2.5190 D(x):0.74 D(G(z)):0.15
# 이폭 [42/500] d_loss:0.6387 g_loss: 2.2579 D(x):0.80 D(G(z)):0.16
# 이폭 [43/500] d_loss:0.5799 g_loss: 2.7580 D(x):0.87 D(G(z)):0.27
# 이폭 [44/500] d_loss:0.7974 g_loss: 2.3027 D(x):0.79 D(G(z)):0.27
# 이폭 [45/500] d_loss:0.5006 g_loss: 2.7973 D(x):0.85 D(G(z)):0.19
# 이폭 [46/500] d_loss:0.4763 g_loss: 2.5302 D(x):0.80 D(G(z)):0.12
# 이폭 [47/500] d_loss:0.4495 g_loss: 2.8868 D(x):0.82 D(G(z)):0.10
# 이폭 [48/500] d_loss:0.4019 g_loss: 2.6597 D(x):0.89 D(G(z)):0.16
# 이폭 [49/500] d_loss:0.5214 g_loss: 2.6681 D(x):0.86 D(G(z)):0.21
# 이폭 [50/500] d_loss:0.4639 g_loss: 2.6363 D(x):0.88 D(G(z)):0.20
# 이폭 [51/500] d_loss:0.6703 g_loss: 2.2425 D(x):0.86 D(G(z)):0.27
# 이폭 [52/500] d_loss:0.7454 g_loss: 1.8817 D(x):0.77 D(G(z)):0.22
# 이폭 [53/500] d_loss:0.6779 g_loss: 1.8096 D(x):0.80 D(G(z)):0.23
# 이폭 [54/500] d_loss:0.6991 g_loss: 2.9767 D(x):0.78 D(G(z)):0.19
# 이폭 [55/500] d_loss:0.7744 g_loss: 2.4500 D(x):0.77 D(G(z)):0.23
# 이폭 [56/500] d_loss:0.6552 g_loss: 2.3739 D(x):0.77 D(G(z)):0.18
# 이폭 [57/500] d_loss:0.6907 g_loss: 2.4750 D(x):0.78 D(G(z)):0.18
# 이폭 [58/500] d_loss:0.8797 g_loss: 1.9353 D(x):0.73 D(G(z)):0.27
# 이폭 [59/500] d_loss:0.4986 g_loss: 2.9366 D(x):0.80 D(G(z)):0.13
# 이폭 [60/500] d_loss:0.6273 g_loss: 2.6954 D(x):0.77 D(G(z)):0.17
# 이폭 [61/500] d_loss:0.4716 g_loss: 2.7883 D(x):0.85 D(G(z)):0.19
# 이폭 [62/500] d_loss:0.9083 g_loss: 2.0955 D(x):0.73 D(G(z)):0.30
# 이폭 [63/500] d_loss:0.7940 g_loss: 1.8386 D(x):0.76 D(G(z)):0.25
# 이폭 [64/500] d_loss:0.7165 g_loss: 2.8932 D(x):0.75 D(G(z)):0.17
# 이폭 [65/500] d_loss:0.6354 g_loss: 2.5690 D(x):0.79 D(G(z)):0.20
# 이폭 [66/500] d_loss:0.7817 g_loss: 2.3922 D(x):0.69 D(G(z)):0.19
# 이폭 [67/500] d_loss:0.6624 g_loss: 2.6789 D(x):0.77 D(G(z)):0.18
# 이폭 [68/500] d_loss:0.6223 g_loss: 2.4107 D(x):0.82 D(G(z)):0.23
# 이폭 [69/500] d_loss:0.6601 g_loss: 2.0014 D(x):0.81 D(G(z)):0.26
# 이폭 [70/500] d_loss:1.1603 g_loss: 2.4121 D(x):0.66 D(G(z)):0.25
# 이폭 [71/500] d_loss:0.8582 g_loss: 2.4326 D(x):0.72 D(G(z)):0.23
# 이폭 [72/500] d_loss:0.6142 g_loss: 2.7208 D(x):0.78 D(G(z)):0.17
# 이폭 [73/500] d_loss:1.0197 g_loss: 1.8418 D(x):0.71 D(G(z)):0.27
# 이폭 [74/500] d_loss:0.9118 g_loss: 2.0126 D(x):0.71 D(G(z)):0.23
# 이폭 [75/500] d_loss:0.6542 g_loss: 1.9000 D(x):0.77 D(G(z)):0.20
# 이폭 [76/500] d_loss:0.9861 g_loss: 1.8889 D(x):0.68 D(G(z)):0.27
# 이폭 [77/500] d_loss:0.9144 g_loss: 2.0052 D(x):0.70 D(G(z)):0.25
# 이폭 [78/500] d_loss:0.7322 g_loss: 1.9463 D(x):0.77 D(G(z)):0.25
# 이폭 [79/500] d_loss:0.7832 g_loss: 1.9815 D(x):0.76 D(G(z)):0.26
# 이폭 [80/500] d_loss:0.7529 g_loss: 2.3857 D(x):0.78 D(G(z)):0.26
# 이폭 [81/500] d_loss:0.8706 g_loss: 1.5544 D(x):0.74 D(G(z)):0.31
# 이폭 [82/500] d_loss:1.0332 g_loss: 1.8416 D(x):0.68 D(G(z)):0.25
# 이폭 [83/500] d_loss:1.1927 g_loss: 1.7061 D(x):0.67 D(G(z)):0.34
# 이폭 [84/500] d_loss:0.7180 g_loss: 1.9957 D(x):0.77 D(G(z)):0.27
# 이폭 [85/500] d_loss:0.7406 g_loss: 1.9239 D(x):0.78 D(G(z)):0.27
# 이폭 [86/500] d_loss:0.9146 g_loss: 1.8860 D(x):0.72 D(G(z)):0.28
# 이폭 [87/500] d_loss:0.7930 g_loss: 2.3140 D(x):0.76 D(G(z)):0.24
# 이폭 [88/500] d_loss:0.8852 g_loss: 1.9547 D(x):0.71 D(G(z)):0.23
# 이폭 [89/500] d_loss:0.8222 g_loss: 2.1475 D(x):0.74 D(G(z)):0.21
# 이폭 [90/500] d_loss:0.7474 g_loss: 1.9551 D(x):0.75 D(G(z)):0.21
# 이폭 [91/500] d_loss:0.7937 g_loss: 1.8969 D(x):0.79 D(G(z)):0.29
# 이폭 [92/500] d_loss:0.9545 g_loss: 1.2800 D(x):0.75 D(G(z)):0.35
# 이폭 [93/500] d_loss:0.7509 g_loss: 2.0087 D(x):0.82 D(G(z)):0.32
# 이폭 [94/500] d_loss:1.0273 g_loss: 1.9271 D(x):0.71 D(G(z)):0.29
# 이폭 [95/500] d_loss:0.5861 g_loss: 2.4204 D(x):0.78 D(G(z)):0.20
# 이폭 [96/500] d_loss:0.6858 g_loss: 2.3049 D(x):0.72 D(G(z)):0.18
# 이폭 [97/500] d_loss:0.8285 g_loss: 2.2240 D(x):0.74 D(G(z)):0.25
# 이폭 [98/500] d_loss:0.8604 g_loss: 2.0749 D(x):0.74 D(G(z)):0.30
# 이폭 [99/500] d_loss:0.9260 g_loss: 1.6631 D(x):0.81 D(G(z)):0.35
# 이폭 [100/500] d_loss:0.7919 g_loss: 1.8946 D(x):0.75 D(G(z)):0.25
# 이폭 [101/500] d_loss:0.9281 g_loss: 1.8890 D(x):0.68 D(G(z)):0.29
# 이폭 [102/500] d_loss:0.9646 g_loss: 1.5796 D(x):0.69 D(G(z)):0.32
# 이폭 [103/500] d_loss:0.9010 g_loss: 1.9638 D(x):0.75 D(G(z)):0.33
# 이폭 [104/500] d_loss:1.1012 g_loss: 1.6935 D(x):0.66 D(G(z)):0.33
# 이폭 [105/500] d_loss:0.9708 g_loss: 1.6774 D(x):0.66 D(G(z)):0.27
# 이폭 [106/500] d_loss:0.9357 g_loss: 1.7026 D(x):0.64 D(G(z)):0.25
# 이폭 [107/500] d_loss:0.9095 g_loss: 1.6945 D(x):0.70 D(G(z)):0.28
# 이폭 [108/500] d_loss:0.9068 g_loss: 1.9013 D(x):0.71 D(G(z)):0.28
# 이폭 [109/500] d_loss:0.8456 g_loss: 1.6792 D(x):0.72 D(G(z)):0.27
# 이폭 [110/500] d_loss:1.0624 g_loss: 1.4296 D(x):0.69 D(G(z)):0.36
# 이폭 [111/500] d_loss:0.8853 g_loss: 1.8104 D(x):0.70 D(G(z)):0.28
# 이폭 [112/500] d_loss:0.8941 g_loss: 1.7667 D(x):0.70 D(G(z)):0.28
# 이폭 [113/500] d_loss:0.8224 g_loss: 2.0401 D(x):0.70 D(G(z)):0.22
# 이폭 [114/500] d_loss:0.7937 g_loss: 2.0197 D(x):0.72 D(G(z)):0.25
# 이폭 [115/500] d_loss:1.0437 g_loss: 1.3365 D(x):0.74 D(G(z)):0.39
# 이폭 [116/500] d_loss:1.0344 g_loss: 1.5576 D(x):0.62 D(G(z)):0.27
# 이폭 [117/500] d_loss:1.2011 g_loss: 1.7052 D(x):0.57 D(G(z)):0.27
# 이폭 [118/500] d_loss:1.0253 g_loss: 1.8168 D(x):0.61 D(G(z)):0.25
# 이폭 [119/500] d_loss:0.9276 g_loss: 1.8999 D(x):0.69 D(G(z)):0.26
# 이폭 [120/500] d_loss:0.8804 g_loss: 1.8023 D(x):0.78 D(G(z)):0.34
# 이폭 [121/500] d_loss:0.9011 g_loss: 1.5946 D(x):0.72 D(G(z)):0.31
# 이폭 [122/500] d_loss:1.0929 g_loss: 1.4403 D(x):0.72 D(G(z)):0.39
# 이폭 [123/500] d_loss:0.9002 g_loss: 1.3113 D(x):0.74 D(G(z)):0.36
# 이폭 [124/500] d_loss:0.6055 g_loss: 2.1249 D(x):0.85 D(G(z)):0.27
# 이폭 [125/500] d_loss:1.0104 g_loss: 1.6574 D(x):0.66 D(G(z)):0.29
# 이폭 [126/500] d_loss:0.6875 g_loss: 1.7155 D(x):0.79 D(G(z)):0.27
# 이폭 [127/500] d_loss:0.9741 g_loss: 1.6658 D(x):0.68 D(G(z)):0.30
# 이폭 [128/500] d_loss:0.9038 g_loss: 1.3681 D(x):0.72 D(G(z)):0.36
# 이폭 [129/500] d_loss:1.0031 g_loss: 1.6115 D(x):0.65 D(G(z)):0.31
# 이폭 [130/500] d_loss:0.9412 g_loss: 1.4807 D(x):0.75 D(G(z)):0.35
# 이폭 [131/500] d_loss:1.0270 g_loss: 1.3831 D(x):0.72 D(G(z)):0.37
# 이폭 [132/500] d_loss:0.9836 g_loss: 1.8578 D(x):0.76 D(G(z)):0.36
# 이폭 [133/500] d_loss:0.8778 g_loss: 1.7403 D(x):0.69 D(G(z)):0.26
# 이폭 [134/500] d_loss:0.9478 g_loss: 1.3645 D(x):0.69 D(G(z)):0.31
# 이폭 [135/500] d_loss:0.9409 g_loss: 1.6461 D(x):0.68 D(G(z)):0.27
# 이폭 [136/500] d_loss:0.9940 g_loss: 1.6737 D(x):0.61 D(G(z)):0.26
# 이폭 [137/500] d_loss:1.0732 g_loss: 1.6432 D(x):0.63 D(G(z)):0.31
# 이폭 [138/500] d_loss:1.0560 g_loss: 1.3007 D(x):0.71 D(G(z)):0.39
# 이폭 [139/500] d_loss:0.7890 g_loss: 1.5859 D(x):0.72 D(G(z)):0.26
# 이폭 [140/500] d_loss:1.0383 g_loss: 1.5055 D(x):0.65 D(G(z)):0.33
# 이폭 [141/500] d_loss:1.2796 g_loss: 1.4436 D(x):0.66 D(G(z)):0.43
# 이폭 [142/500] d_loss:0.9152 g_loss: 1.5738 D(x):0.69 D(G(z)):0.31
# 이폭 [143/500] d_loss:1.1517 g_loss: 1.4954 D(x):0.58 D(G(z)):0.28
# 이폭 [144/500] d_loss:0.9795 g_loss: 1.5292 D(x):0.77 D(G(z)):0.39
# 이폭 [145/500] d_loss:0.8651 g_loss: 1.8336 D(x):0.72 D(G(z)):0.29
# 이폭 [146/500] d_loss:0.9119 g_loss: 1.5847 D(x):0.67 D(G(z)):0.27
# 이폭 [147/500] d_loss:1.2104 g_loss: 1.2083 D(x):0.67 D(G(z)):0.41
# 이폭 [148/500] d_loss:1.1242 g_loss: 1.2049 D(x):0.72 D(G(z)):0.43
# 이폭 [149/500] d_loss:1.0847 g_loss: 1.1952 D(x):0.68 D(G(z)):0.40
# 이폭 [150/500] d_loss:0.9253 g_loss: 1.5050 D(x):0.66 D(G(z)):0.29
# 이폭 [151/500] d_loss:1.0354 g_loss: 1.5787 D(x):0.62 D(G(z)):0.29
# 이폭 [152/500] d_loss:1.0001 g_loss: 1.4842 D(x):0.70 D(G(z)):0.35
# 이폭 [153/500] d_loss:0.8035 g_loss: 2.0234 D(x):0.75 D(G(z)):0.27
# 이폭 [154/500] d_loss:0.8909 g_loss: 1.5160 D(x):0.75 D(G(z)):0.33
# 이폭 [155/500] d_loss:0.9891 g_loss: 1.4780 D(x):0.68 D(G(z)):0.33
# 이폭 [156/500] d_loss:0.8507 g_loss: 1.8071 D(x):0.69 D(G(z)):0.25
# 이폭 [157/500] d_loss:0.9528 g_loss: 1.6055 D(x):0.72 D(G(z)):0.37
# 이폭 [158/500] d_loss:0.9130 g_loss: 1.5038 D(x):0.68 D(G(z)):0.28
# 이폭 [159/500] d_loss:0.9967 g_loss: 1.5760 D(x):0.64 D(G(z)):0.30
# 이폭 [160/500] d_loss:1.0505 g_loss: 1.3453 D(x):0.66 D(G(z)):0.36
# 이폭 [161/500] d_loss:0.9963 g_loss: 1.3546 D(x):0.67 D(G(z)):0.35
# 이폭 [162/500] d_loss:0.8998 g_loss: 1.4299 D(x):0.72 D(G(z)):0.30
# 이폭 [163/500] d_loss:1.0353 g_loss: 1.5759 D(x):0.65 D(G(z)):0.28
# 이폭 [164/500] d_loss:0.8674 g_loss: 1.5915 D(x):0.70 D(G(z)):0.29
# 이폭 [165/500] d_loss:1.3252 g_loss: 1.1499 D(x):0.64 D(G(z)):0.42
# 이폭 [166/500] d_loss:1.0967 g_loss: 1.3353 D(x):0.67 D(G(z)):0.37
# 이폭 [167/500] d_loss:1.0930 g_loss: 1.4632 D(x):0.66 D(G(z)):0.35
# 이폭 [168/500] d_loss:1.2955 g_loss: 1.0810 D(x):0.68 D(G(z)):0.45
# 이폭 [169/500] d_loss:0.9686 g_loss: 1.4582 D(x):0.71 D(G(z)):0.34
# 이폭 [170/500] d_loss:1.1974 g_loss: 1.5520 D(x):0.59 D(G(z)):0.33
# 이폭 [171/500] d_loss:0.9430 g_loss: 1.7329 D(x):0.68 D(G(z)):0.31
# 이폭 [172/500] d_loss:0.9323 g_loss: 1.4252 D(x):0.67 D(G(z)):0.32
# 이폭 [173/500] d_loss:0.9885 g_loss: 1.4994 D(x):0.68 D(G(z)):0.33
# 이폭 [174/500] d_loss:0.9361 g_loss: 1.5630 D(x):0.73 D(G(z)):0.37
# 이폭 [175/500] d_loss:0.8780 g_loss: 1.6493 D(x):0.71 D(G(z)):0.31
# 이폭 [176/500] d_loss:1.1184 g_loss: 1.3338 D(x):0.62 D(G(z)):0.34
# 이폭 [177/500] d_loss:0.9055 g_loss: 1.6966 D(x):0.71 D(G(z)):0.30
# 이폭 [178/500] d_loss:0.8138 g_loss: 1.5999 D(x):0.74 D(G(z)):0.31
# 이폭 [179/500] d_loss:0.9984 g_loss: 1.4118 D(x):0.64 D(G(z)):0.31
# 이폭 [180/500] d_loss:0.8357 g_loss: 1.4382 D(x):0.70 D(G(z)):0.27
# 이폭 [181/500] d_loss:0.9783 g_loss: 1.4534 D(x):0.69 D(G(z)):0.33
# 이폭 [182/500] d_loss:1.3245 g_loss: 1.3685 D(x):0.65 D(G(z)):0.43
# 이폭 [183/500] d_loss:0.9553 g_loss: 1.3394 D(x):0.69 D(G(z)):0.35
# 이폭 [184/500] d_loss:1.1100 g_loss: 1.2222 D(x):0.62 D(G(z)):0.36
# 이폭 [185/500] d_loss:0.9080 g_loss: 1.8574 D(x):0.67 D(G(z)):0.27
# 이폭 [186/500] d_loss:1.0587 g_loss: 1.6277 D(x):0.65 D(G(z)):0.32
# 이폭 [187/500] d_loss:0.9486 g_loss: 1.5804 D(x):0.64 D(G(z)):0.27
# 이폭 [188/500] d_loss:0.9881 g_loss: 1.2094 D(x):0.76 D(G(z)):0.42
# 이폭 [189/500] d_loss:1.1224 g_loss: 1.2044 D(x):0.82 D(G(z)):0.47
# 이폭 [190/500] d_loss:0.8597 g_loss: 1.8911 D(x):0.74 D(G(z)):0.29
# 이폭 [191/500] d_loss:0.8071 g_loss: 1.6270 D(x):0.73 D(G(z)):0.28
# 이폭 [192/500] d_loss:1.2524 g_loss: 1.2391 D(x):0.58 D(G(z)):0.38
# 이폭 [193/500] d_loss:0.9147 g_loss: 1.7606 D(x):0.66 D(G(z)):0.27
# 이폭 [194/500] d_loss:0.9284 g_loss: 1.6519 D(x):0.72 D(G(z)):0.34
# 이폭 [195/500] d_loss:1.0080 g_loss: 1.5618 D(x):0.62 D(G(z)):0.27
# 이폭 [196/500] d_loss:0.8817 g_loss: 1.3600 D(x):0.68 D(G(z)):0.30
# 이폭 [197/500] d_loss:1.1652 g_loss: 1.5129 D(x):0.65 D(G(z)):0.37
# 이폭 [198/500] d_loss:1.1175 g_loss: 1.3403 D(x):0.68 D(G(z)):0.41
# 이폭 [199/500] d_loss:0.8182 g_loss: 1.5587 D(x):0.72 D(G(z)):0.29
# 이폭 [200/500] d_loss:0.7009 g_loss: 1.8949 D(x):0.76 D(G(z)):0.27
# 이폭 [201/500] d_loss:1.0769 g_loss: 1.1866 D(x):0.69 D(G(z)):0.41
# 이폭 [202/500] d_loss:1.0725 g_loss: 1.1395 D(x):0.68 D(G(z)):0.40
# 이폭 [203/500] d_loss:1.1328 g_loss: 1.2746 D(x):0.61 D(G(z)):0.35
# 이폭 [204/500] d_loss:0.8085 g_loss: 1.6316 D(x):0.70 D(G(z)):0.28
# 이폭 [205/500] d_loss:1.2818 g_loss: 1.5960 D(x):0.58 D(G(z)):0.30
# 이폭 [206/500] d_loss:1.2172 g_loss: 1.3409 D(x):0.56 D(G(z)):0.33
# 이폭 [207/500] d_loss:0.8791 g_loss: 1.1539 D(x):0.73 D(G(z)):0.36
# 이폭 [208/500] d_loss:1.0125 g_loss: 1.4653 D(x):0.67 D(G(z)):0.33
# 이폭 [209/500] d_loss:0.9484 g_loss: 1.3294 D(x):0.70 D(G(z)):0.34
# 이폭 [210/500] d_loss:0.6334 g_loss: 1.8166 D(x):0.77 D(G(z)):0.24
# 이폭 [211/500] d_loss:1.0138 g_loss: 1.4014 D(x):0.66 D(G(z)):0.34
# 이폭 [212/500] d_loss:0.8815 g_loss: 1.6793 D(x):0.69 D(G(z)):0.28
# 이폭 [213/500] d_loss:0.8270 g_loss: 1.6216 D(x):0.70 D(G(z)):0.28
# 이폭 [214/500] d_loss:0.9083 g_loss: 1.3549 D(x):0.75 D(G(z)):0.37
# 이폭 [215/500] d_loss:1.1527 g_loss: 1.5640 D(x):0.58 D(G(z)):0.28
# 이폭 [216/500] d_loss:0.9507 g_loss: 1.5009 D(x):0.69 D(G(z)):0.31
# 이폭 [217/500] d_loss:1.2321 g_loss: 1.3205 D(x):0.59 D(G(z)):0.35
# 이폭 [218/500] d_loss:0.9576 g_loss: 1.4605 D(x):0.71 D(G(z)):0.34
# 이폭 [219/500] d_loss:1.4464 g_loss: 1.2298 D(x):0.62 D(G(z)):0.46
# 이폭 [220/500] d_loss:1.1780 g_loss: 1.1574 D(x):0.69 D(G(z)):0.44
# 이폭 [221/500] d_loss:1.0336 g_loss: 1.3533 D(x):0.66 D(G(z)):0.36
# 이폭 [222/500] d_loss:1.0960 g_loss: 1.4026 D(x):0.64 D(G(z)):0.35
# 이폭 [223/500] d_loss:1.3187 g_loss: 1.1970 D(x):0.60 D(G(z)):0.39
# 이폭 [224/500] d_loss:1.0721 g_loss: 1.3713 D(x):0.65 D(G(z)):0.36
# 이폭 [225/500] d_loss:0.7719 g_loss: 1.7152 D(x):0.72 D(G(z)):0.28
# 이폭 [226/500] d_loss:1.1162 g_loss: 1.4885 D(x):0.65 D(G(z)):0.34
# 이폭 [227/500] d_loss:1.0168 g_loss: 1.4935 D(x):0.66 D(G(z)):0.34
# 이폭 [228/500] d_loss:0.8479 g_loss: 1.6035 D(x):0.68 D(G(z)):0.27
# 이폭 [229/500] d_loss:1.2603 g_loss: 1.0969 D(x):0.64 D(G(z)):0.44
# 이폭 [230/500] d_loss:0.9844 g_loss: 1.4800 D(x):0.64 D(G(z)):0.30
# 이폭 [231/500] d_loss:0.6588 g_loss: 1.8243 D(x):0.78 D(G(z)):0.25
# 이폭 [232/500] d_loss:1.2831 g_loss: 1.4050 D(x):0.57 D(G(z)):0.33
# 이폭 [233/500] d_loss:0.8163 g_loss: 1.9654 D(x):0.69 D(G(z)):0.23
# 이폭 [234/500] d_loss:0.7922 g_loss: 1.8447 D(x):0.74 D(G(z)):0.28
# 이폭 [235/500] d_loss:1.2745 g_loss: 1.2825 D(x):0.62 D(G(z)):0.41
# 이폭 [236/500] d_loss:1.0202 g_loss: 1.3911 D(x):0.70 D(G(z)):0.37
# 이폭 [237/500] d_loss:0.7884 g_loss: 1.7060 D(x):0.71 D(G(z)):0.27
# 이폭 [238/500] d_loss:0.8066 g_loss: 1.4520 D(x):0.70 D(G(z)):0.28
# 이폭 [239/500] d_loss:0.8798 g_loss: 1.5334 D(x):0.69 D(G(z)):0.31
# 이폭 [240/500] d_loss:0.9801 g_loss: 1.5301 D(x):0.67 D(G(z)):0.31
# 이폭 [241/500] d_loss:0.8767 g_loss: 1.7338 D(x):0.66 D(G(z)):0.26
# 이폭 [242/500] d_loss:1.0193 g_loss: 1.3442 D(x):0.64 D(G(z)):0.33
# 이폭 [243/500] d_loss:0.9451 g_loss: 1.5079 D(x):0.73 D(G(z)):0.34
# 이폭 [244/500] d_loss:0.8321 g_loss: 1.6833 D(x):0.69 D(G(z)):0.28
# 이폭 [245/500] d_loss:0.7373 g_loss: 1.7219 D(x):0.73 D(G(z)):0.26
# 이폭 [246/500] d_loss:1.0442 g_loss: 1.2760 D(x):0.67 D(G(z)):0.35
# 이폭 [247/500] d_loss:1.0719 g_loss: 1.6899 D(x):0.63 D(G(z)):0.29
# 이폭 [248/500] d_loss:0.9615 g_loss: 1.7573 D(x):0.64 D(G(z)):0.22
# 이폭 [249/500] d_loss:0.9998 g_loss: 1.3594 D(x):0.65 D(G(z)):0.33
# 이폭 [250/500] d_loss:0.8494 g_loss: 1.8647 D(x):0.69 D(G(z)):0.26
# 이폭 [251/500] d_loss:0.7195 g_loss: 1.4083 D(x):0.75 D(G(z)):0.28
# 이폭 [252/500] d_loss:1.0976 g_loss: 1.3764 D(x):0.66 D(G(z)):0.38
# 이폭 [253/500] d_loss:1.1544 g_loss: 1.2630 D(x):0.66 D(G(z)):0.42
# 이폭 [254/500] d_loss:0.9892 g_loss: 1.4675 D(x):0.66 D(G(z)):0.31
# 이폭 [255/500] d_loss:1.1173 g_loss: 1.3522 D(x):0.66 D(G(z)):0.37
# 이폭 [256/500] d_loss:1.1909 g_loss: 1.3051 D(x):0.62 D(G(z)):0.36
# 이폭 [257/500] d_loss:1.0588 g_loss: 1.5702 D(x):0.61 D(G(z)):0.31
# 이폭 [258/500] d_loss:0.9008 g_loss: 1.4457 D(x):0.69 D(G(z)):0.32
# 이폭 [259/500] d_loss:0.9147 g_loss: 1.5422 D(x):0.72 D(G(z)):0.32
# 이폭 [260/500] d_loss:1.0346 g_loss: 1.6851 D(x):0.67 D(G(z)):0.30
# 이폭 [261/500] d_loss:1.0336 g_loss: 1.2964 D(x):0.67 D(G(z)):0.36
# 이폭 [262/500] d_loss:1.1548 g_loss: 1.2382 D(x):0.59 D(G(z)):0.33
# 이폭 [263/500] d_loss:0.9742 g_loss: 1.2732 D(x):0.70 D(G(z)):0.36
# 이폭 [264/500] d_loss:0.8308 g_loss: 1.4192 D(x):0.73 D(G(z)):0.33
# 이폭 [265/500] d_loss:1.0106 g_loss: 1.3159 D(x):0.64 D(G(z)):0.34
# 이폭 [266/500] d_loss:0.6846 g_loss: 1.6776 D(x):0.76 D(G(z)):0.27
# 이폭 [267/500] d_loss:1.2198 g_loss: 1.4215 D(x):0.58 D(G(z)):0.33
# 이폭 [268/500] d_loss:0.8917 g_loss: 1.7425 D(x):0.63 D(G(z)):0.24
# 이폭 [269/500] d_loss:0.9112 g_loss: 1.6696 D(x):0.68 D(G(z)):0.28
# 이폭 [270/500] d_loss:1.0614 g_loss: 1.4774 D(x):0.68 D(G(z)):0.35
# 이폭 [271/500] d_loss:1.3120 g_loss: 1.1201 D(x):0.62 D(G(z)):0.43
# 이폭 [272/500] d_loss:1.0925 g_loss: 1.1252 D(x):0.67 D(G(z)):0.41
# 이폭 [273/500] d_loss:0.9538 g_loss: 1.3318 D(x):0.71 D(G(z)):0.35
# 이폭 [274/500] d_loss:0.7580 g_loss: 1.5790 D(x):0.74 D(G(z)):0.29
# 이폭 [275/500] d_loss:1.0205 g_loss: 1.6390 D(x):0.60 D(G(z)):0.28
# 이폭 [276/500] d_loss:1.5283 g_loss: 1.1689 D(x):0.51 D(G(z)):0.42
# 이폭 [277/500] d_loss:1.0048 g_loss: 1.3596 D(x):0.64 D(G(z)):0.33
# 이폭 [278/500] d_loss:1.0379 g_loss: 1.5805 D(x):0.64 D(G(z)):0.31
# 이폭 [279/500] d_loss:0.8545 g_loss: 1.5028 D(x):0.68 D(G(z)):0.29
# 이폭 [280/500] d_loss:0.9990 g_loss: 1.4197 D(x):0.66 D(G(z)):0.34
# 이폭 [281/500] d_loss:1.1141 g_loss: 1.4672 D(x):0.58 D(G(z)):0.29
# 이폭 [282/500] d_loss:1.1771 g_loss: 1.2881 D(x):0.57 D(G(z)):0.34
# 이폭 [283/500] d_loss:0.7444 g_loss: 1.5254 D(x):0.74 D(G(z)):0.29
# 이폭 [284/500] d_loss:0.7648 g_loss: 1.6756 D(x):0.71 D(G(z)):0.26
# 이폭 [285/500] d_loss:1.5136 g_loss: 0.9314 D(x):0.58 D(G(z)):0.48
# 이폭 [286/500] d_loss:1.2895 g_loss: 1.1155 D(x):0.58 D(G(z)):0.40
# 이폭 [287/500] d_loss:0.9952 g_loss: 1.3499 D(x):0.69 D(G(z)):0.35
# 이폭 [288/500] d_loss:1.0547 g_loss: 1.2962 D(x):0.68 D(G(z)):0.37
# 이폭 [289/500] d_loss:0.9689 g_loss: 1.4880 D(x):0.72 D(G(z)):0.35
# 이폭 [290/500] d_loss:1.1005 g_loss: 1.3856 D(x):0.61 D(G(z)):0.34
# 이폭 [291/500] d_loss:1.2599 g_loss: 1.2477 D(x):0.58 D(G(z)):0.37
# 이폭 [292/500] d_loss:0.8775 g_loss: 1.5740 D(x):0.70 D(G(z)):0.30
# 이폭 [293/500] d_loss:0.9589 g_loss: 1.5202 D(x):0.70 D(G(z)):0.34
# 이폭 [294/500] d_loss:1.1898 g_loss: 1.2690 D(x):0.62 D(G(z)):0.38
# 이폭 [295/500] d_loss:1.3389 g_loss: 1.2068 D(x):0.59 D(G(z)):0.41
# 이폭 [296/500] d_loss:1.2872 g_loss: 1.2897 D(x):0.57 D(G(z)):0.36
# 이폭 [297/500] d_loss:1.1085 g_loss: 1.2949 D(x):0.67 D(G(z)):0.39
# 이폭 [298/500] d_loss:0.7592 g_loss: 1.6001 D(x):0.75 D(G(z)):0.29
# 이폭 [299/500] d_loss:1.0142 g_loss: 1.3787 D(x):0.66 D(G(z)):0.33
# 이폭 [300/500] d_loss:1.3307 g_loss: 1.2391 D(x):0.60 D(G(z)):0.38
# 이폭 [301/500] d_loss:0.9413 g_loss: 1.6214 D(x):0.70 D(G(z)):0.32
# 이폭 [302/500] d_loss:1.3085 g_loss: 1.2997 D(x):0.53 D(G(z)):0.34
# 이폭 [303/500] d_loss:1.0900 g_loss: 1.4443 D(x):0.59 D(G(z)):0.31
# 이폭 [304/500] d_loss:0.7102 g_loss: 1.7627 D(x):0.76 D(G(z)):0.26
# 이폭 [305/500] d_loss:1.0246 g_loss: 1.3697 D(x):0.67 D(G(z)):0.35
# 이폭 [306/500] d_loss:1.0437 g_loss: 1.4403 D(x):0.67 D(G(z)):0.35
# 이폭 [307/500] d_loss:0.8574 g_loss: 1.4594 D(x):0.74 D(G(z)):0.34
# 이폭 [308/500] d_loss:1.4585 g_loss: 1.1667 D(x):0.55 D(G(z)):0.42
# 이폭 [309/500] d_loss:0.7436 g_loss: 1.6489 D(x):0.73 D(G(z)):0.27
# 이폭 [310/500] d_loss:1.1018 g_loss: 1.3182 D(x):0.65 D(G(z)):0.37
# 이폭 [311/500] d_loss:1.1198 g_loss: 1.4273 D(x):0.63 D(G(z)):0.34
# 이폭 [312/500] d_loss:1.2627 g_loss: 1.2348 D(x):0.60 D(G(z)):0.36
# 이폭 [313/500] d_loss:0.8875 g_loss: 1.6622 D(x):0.69 D(G(z)):0.29
# 이폭 [314/500] d_loss:0.8417 g_loss: 1.7631 D(x):0.66 D(G(z)):0.23
# 이폭 [315/500] d_loss:1.1045 g_loss: 1.1116 D(x):0.69 D(G(z)):0.41
# 이폭 [316/500] d_loss:1.0640 g_loss: 1.3754 D(x):0.63 D(G(z)):0.33
# 이폭 [317/500] d_loss:0.7773 g_loss: 1.7153 D(x):0.70 D(G(z)):0.25
# 이폭 [318/500] d_loss:0.9059 g_loss: 1.5833 D(x):0.69 D(G(z)):0.31
# 이폭 [319/500] d_loss:0.9402 g_loss: 1.4784 D(x):0.69 D(G(z)):0.32
# 이폭 [320/500] d_loss:0.8262 g_loss: 1.7164 D(x):0.66 D(G(z)):0.24
# 이폭 [321/500] d_loss:1.3090 g_loss: 1.1538 D(x):0.57 D(G(z)):0.39
# 이폭 [322/500] d_loss:1.4767 g_loss: 1.0945 D(x):0.56 D(G(z)):0.44
# 이폭 [323/500] d_loss:0.8576 g_loss: 1.5093 D(x):0.73 D(G(z)):0.31
# 이폭 [324/500] d_loss:0.9942 g_loss: 1.4823 D(x):0.62 D(G(z)):0.28
# 이폭 [325/500] d_loss:1.0820 g_loss: 1.2711 D(x):0.63 D(G(z)):0.35
# 이폭 [326/500] d_loss:0.9038 g_loss: 1.2868 D(x):0.75 D(G(z)):0.37
# 이폭 [327/500] d_loss:1.0699 g_loss: 1.5222 D(x):0.61 D(G(z)):0.31
# 이폭 [328/500] d_loss:0.6703 g_loss: 1.5801 D(x):0.82 D(G(z)):0.30
# 이폭 [329/500] d_loss:1.2027 g_loss: 1.1166 D(x):0.67 D(G(z)):0.43
# 이폭 [330/500] d_loss:1.1331 g_loss: 1.3005 D(x):0.64 D(G(z)):0.35
# 이폭 [331/500] d_loss:0.9082 g_loss: 1.4926 D(x):0.69 D(G(z)):0.31
# 이폭 [332/500] d_loss:1.2120 g_loss: 1.1749 D(x):0.63 D(G(z)):0.39
# 이폭 [333/500] d_loss:0.7908 g_loss: 1.7631 D(x):0.72 D(G(z)):0.27
# 이폭 [334/500] d_loss:0.8412 g_loss: 1.6893 D(x):0.69 D(G(z)):0.27
# 이폭 [335/500] d_loss:1.3098 g_loss: 1.3332 D(x):0.58 D(G(z)):0.39
# 이폭 [336/500] d_loss:1.1220 g_loss: 1.2953 D(x):0.61 D(G(z)):0.35
# 이폭 [337/500] d_loss:1.3492 g_loss: 1.0757 D(x):0.61 D(G(z)):0.45
# 이폭 [338/500] d_loss:0.7631 g_loss: 1.5140 D(x):0.73 D(G(z)):0.29
# 이폭 [339/500] d_loss:0.7704 g_loss: 1.6692 D(x):0.72 D(G(z)):0.28
# 이폭 [340/500] d_loss:0.7443 g_loss: 1.4619 D(x):0.78 D(G(z)):0.32
# 이폭 [341/500] d_loss:1.1296 g_loss: 1.3762 D(x):0.60 D(G(z)):0.34
# 이폭 [342/500] d_loss:0.8980 g_loss: 1.5226 D(x):0.66 D(G(z)):0.29
# 이폭 [343/500] d_loss:1.0183 g_loss: 1.3923 D(x):0.69 D(G(z)):0.34
# 이폭 [344/500] d_loss:1.0409 g_loss: 1.4268 D(x):0.61 D(G(z)):0.31
# 이폭 [345/500] d_loss:1.1931 g_loss: 1.2471 D(x):0.63 D(G(z)):0.39
# 이폭 [346/500] d_loss:1.2491 g_loss: 1.1138 D(x):0.61 D(G(z)):0.40
# 이폭 [347/500] d_loss:0.9242 g_loss: 1.3633 D(x):0.70 D(G(z)):0.34
# 이폭 [348/500] d_loss:0.7289 g_loss: 1.8386 D(x):0.73 D(G(z)):0.23
# 이폭 [349/500] d_loss:0.9920 g_loss: 1.6276 D(x):0.65 D(G(z)):0.28
# 이폭 [350/500] d_loss:0.8564 g_loss: 1.8012 D(x):0.67 D(G(z)):0.25
# 이폭 [351/500] d_loss:1.0359 g_loss: 1.4648 D(x):0.64 D(G(z)):0.33
# 이폭 [352/500] d_loss:0.9386 g_loss: 1.4681 D(x):0.67 D(G(z)):0.33
# 이폭 [353/500] d_loss:1.0934 g_loss: 1.3680 D(x):0.65 D(G(z)):0.35
# 이폭 [354/500] d_loss:1.0989 g_loss: 1.4247 D(x):0.62 D(G(z)):0.33
# 이폭 [355/500] d_loss:1.1525 g_loss: 1.2491 D(x):0.65 D(G(z)):0.38
# 이폭 [356/500] d_loss:0.8407 g_loss: 1.6522 D(x):0.70 D(G(z)):0.28
# 이폭 [357/500] d_loss:0.7630 g_loss: 1.5873 D(x):0.77 D(G(z)):0.30
# 이폭 [358/500] d_loss:0.6183 g_loss: 2.0883 D(x):0.81 D(G(z)):0.23
# 이폭 [359/500] d_loss:1.0203 g_loss: 1.2633 D(x):0.68 D(G(z)):0.36
# 이폭 [360/500] d_loss:1.0190 g_loss: 1.4043 D(x):0.64 D(G(z)):0.33
# 이폭 [361/500] d_loss:0.9562 g_loss: 1.3604 D(x):0.69 D(G(z)):0.35
# 이폭 [362/500] d_loss:1.2111 g_loss: 1.1965 D(x):0.62 D(G(z)):0.39
# 이폭 [363/500] d_loss:0.9292 g_loss: 1.3760 D(x):0.73 D(G(z)):0.36
# 이폭 [364/500] d_loss:0.9254 g_loss: 1.2480 D(x):0.71 D(G(z)):0.36
# 이폭 [365/500] d_loss:0.9211 g_loss: 1.4091 D(x):0.70 D(G(z)):0.33
# 이폭 [366/500] d_loss:0.9605 g_loss: 1.3923 D(x):0.67 D(G(z)):0.32
# 이폭 [367/500] d_loss:1.1597 g_loss: 1.1075 D(x):0.68 D(G(z)):0.42
# 이폭 [368/500] d_loss:0.9303 g_loss: 1.6018 D(x):0.66 D(G(z)):0.27
# 이폭 [369/500] d_loss:0.9833 g_loss: 1.3475 D(x):0.71 D(G(z)):0.34
# 이폭 [370/500] d_loss:1.0473 g_loss: 1.4101 D(x):0.66 D(G(z)):0.37
# 이폭 [371/500] d_loss:0.9093 g_loss: 1.4682 D(x):0.68 D(G(z)):0.32
# 이폭 [372/500] d_loss:0.7852 g_loss: 1.6838 D(x):0.73 D(G(z)):0.28
# 이폭 [373/500] d_loss:0.8115 g_loss: 1.3143 D(x):0.75 D(G(z)):0.32
# 이폭 [374/500] d_loss:0.8743 g_loss: 1.5326 D(x):0.69 D(G(z)):0.30
# 이폭 [375/500] d_loss:1.3339 g_loss: 1.0930 D(x):0.57 D(G(z)):0.40
# 이폭 [376/500] d_loss:0.7510 g_loss: 1.8944 D(x):0.74 D(G(z)):0.26
# 이폭 [377/500] d_loss:0.8924 g_loss: 1.5251 D(x):0.68 D(G(z)):0.29
# 이폭 [378/500] d_loss:1.0397 g_loss: 1.2205 D(x):0.68 D(G(z)):0.38
# 이폭 [379/500] d_loss:0.9294 g_loss: 1.5250 D(x):0.68 D(G(z)):0.30
# 이폭 [380/500] d_loss:0.9559 g_loss: 1.4623 D(x):0.66 D(G(z)):0.30
# 이폭 [381/500] d_loss:0.9182 g_loss: 1.3449 D(x):0.67 D(G(z)):0.31
# 이폭 [382/500] d_loss:1.0860 g_loss: 1.4285 D(x):0.65 D(G(z)):0.32
# 이폭 [383/500] d_loss:0.9161 g_loss: 1.5432 D(x):0.71 D(G(z)):0.31
# 이폭 [384/500] d_loss:1.0039 g_loss: 1.4526 D(x):0.70 D(G(z)):0.34
# 이폭 [385/500] d_loss:0.9734 g_loss: 1.5233 D(x):0.65 D(G(z)):0.29
# 이폭 [386/500] d_loss:0.8056 g_loss: 1.6659 D(x):0.70 D(G(z)):0.26
# 이폭 [387/500] d_loss:1.1659 g_loss: 1.2195 D(x):0.66 D(G(z)):0.39
# 이폭 [388/500] d_loss:1.0917 g_loss: 1.2922 D(x):0.67 D(G(z)):0.36
# 이폭 [389/500] d_loss:1.1338 g_loss: 1.4569 D(x):0.58 D(G(z)):0.30
# 이폭 [390/500] d_loss:0.8841 g_loss: 1.5154 D(x):0.71 D(G(z)):0.32
# 이폭 [391/500] d_loss:0.7810 g_loss: 1.5137 D(x):0.77 D(G(z)):0.30
# 이폭 [392/500] d_loss:0.8847 g_loss: 1.4338 D(x):0.71 D(G(z)):0.31
# 이폭 [393/500] d_loss:0.6619 g_loss: 1.5595 D(x):0.78 D(G(z)):0.27
# 이폭 [394/500] d_loss:1.1027 g_loss: 1.3696 D(x):0.63 D(G(z)):0.34
# 이폭 [395/500] d_loss:0.9785 g_loss: 1.4293 D(x):0.67 D(G(z)):0.34
# 이폭 [396/500] d_loss:1.3354 g_loss: 1.0880 D(x):0.59 D(G(z)):0.41
# 이폭 [397/500] d_loss:1.1482 g_loss: 1.2052 D(x):0.65 D(G(z)):0.38
# 이폭 [398/500] d_loss:1.1793 g_loss: 1.2985 D(x):0.65 D(G(z)):0.36
# 이폭 [399/500] d_loss:1.0783 g_loss: 1.4436 D(x):0.63 D(G(z)):0.31
# 이폭 [400/500] d_loss:0.9376 g_loss: 1.4199 D(x):0.67 D(G(z)):0.32
# 이폭 [401/500] d_loss:1.0304 g_loss: 1.5524 D(x):0.62 D(G(z)):0.28
# 이폭 [402/500] d_loss:1.1046 g_loss: 1.1676 D(x):0.68 D(G(z)):0.39
# 이폭 [403/500] d_loss:1.2944 g_loss: 1.1832 D(x):0.66 D(G(z)):0.41
# 이폭 [404/500] d_loss:1.1143 g_loss: 1.2516 D(x):0.63 D(G(z)):0.36
# 이폭 [405/500] d_loss:0.9699 g_loss: 1.6109 D(x):0.65 D(G(z)):0.30
# 이폭 [406/500] d_loss:0.8897 g_loss: 1.3110 D(x):0.73 D(G(z)):0.35
# 이폭 [407/500] d_loss:0.9655 g_loss: 1.3651 D(x):0.68 D(G(z)):0.32
# 이폭 [408/500] d_loss:0.6497 g_loss: 1.6119 D(x):0.75 D(G(z)):0.25
# 이폭 [409/500] d_loss:1.1159 g_loss: 1.1839 D(x):0.64 D(G(z)):0.38
# 이폭 [410/500] d_loss:1.1031 g_loss: 1.2683 D(x):0.67 D(G(z)):0.38
# 이폭 [411/500] d_loss:0.9674 g_loss: 1.5591 D(x):0.68 D(G(z)):0.31
# 이폭 [412/500] d_loss:0.8165 g_loss: 1.6770 D(x):0.72 D(G(z)):0.28
# 이폭 [413/500] d_loss:0.9563 g_loss: 1.4788 D(x):0.69 D(G(z)):0.34
# 이폭 [414/500] d_loss:0.9033 g_loss: 1.5267 D(x):0.68 D(G(z)):0.28
# 이폭 [415/500] d_loss:0.9740 g_loss: 1.4067 D(x):0.67 D(G(z)):0.32
# 이폭 [416/500] d_loss:0.8587 g_loss: 1.7366 D(x):0.65 D(G(z)):0.24
# 이폭 [417/500] d_loss:1.0326 g_loss: 1.4641 D(x):0.61 D(G(z)):0.29
# 이폭 [418/500] d_loss:0.8349 g_loss: 1.7588 D(x):0.68 D(G(z)):0.26
# 이폭 [419/500] d_loss:1.2556 g_loss: 1.1178 D(x):0.61 D(G(z)):0.39
# 이폭 [420/500] d_loss:0.9477 g_loss: 1.2214 D(x):0.72 D(G(z)):0.36
# 이폭 [421/500] d_loss:0.8878 g_loss: 1.3695 D(x):0.72 D(G(z)):0.35
# 이폭 [422/500] d_loss:1.0767 g_loss: 1.4680 D(x):0.66 D(G(z)):0.32
# 이폭 [423/500] d_loss:0.9531 g_loss: 1.2376 D(x):0.72 D(G(z)):0.37
# 이폭 [424/500] d_loss:0.9308 g_loss: 1.3770 D(x):0.72 D(G(z)):0.34
# 이폭 [425/500] d_loss:1.1408 g_loss: 1.3412 D(x):0.63 D(G(z)):0.35
# 이폭 [426/500] d_loss:0.7985 g_loss: 1.5459 D(x):0.74 D(G(z)):0.30
# 이폭 [427/500] d_loss:1.0342 g_loss: 1.2419 D(x):0.66 D(G(z)):0.36
# 이폭 [428/500] d_loss:0.9322 g_loss: 1.3503 D(x):0.69 D(G(z)):0.32
# 이폭 [429/500] d_loss:1.0767 g_loss: 1.4431 D(x):0.66 D(G(z)):0.34
# 이폭 [430/500] d_loss:1.1977 g_loss: 1.5266 D(x):0.55 D(G(z)):0.29
# 이폭 [431/500] d_loss:0.8252 g_loss: 1.5664 D(x):0.71 D(G(z)):0.28
# 이폭 [432/500] d_loss:1.0470 g_loss: 1.2227 D(x):0.68 D(G(z)):0.39
# 이폭 [433/500] d_loss:1.1037 g_loss: 1.4164 D(x):0.65 D(G(z)):0.35
# 이폭 [434/500] d_loss:1.0569 g_loss: 1.4347 D(x):0.66 D(G(z)):0.35
# 이폭 [435/500] d_loss:0.9605 g_loss: 1.3955 D(x):0.73 D(G(z)):0.37
# 이폭 [436/500] d_loss:1.2531 g_loss: 1.3096 D(x):0.61 D(G(z)):0.37
# 이폭 [437/500] d_loss:1.2398 g_loss: 1.3613 D(x):0.65 D(G(z)):0.38
# 이폭 [438/500] d_loss:1.0389 g_loss: 1.3607 D(x):0.65 D(G(z)):0.32
# 이폭 [439/500] d_loss:0.8321 g_loss: 1.5390 D(x):0.76 D(G(z)):0.32
# 이폭 [440/500] d_loss:0.8616 g_loss: 1.5060 D(x):0.67 D(G(z)):0.29
# 이폭 [441/500] d_loss:0.7825 g_loss: 1.5562 D(x):0.76 D(G(z)):0.29
# 이폭 [442/500] d_loss:0.8988 g_loss: 1.4801 D(x):0.73 D(G(z)):0.35
# 이폭 [443/500] d_loss:1.0315 g_loss: 1.2853 D(x):0.67 D(G(z)):0.35
# 이폭 [444/500] d_loss:1.0020 g_loss: 1.5700 D(x):0.67 D(G(z)):0.31
# 이폭 [445/500] d_loss:0.9810 g_loss: 1.4206 D(x):0.68 D(G(z)):0.34
# 이폭 [446/500] d_loss:0.8831 g_loss: 1.6291 D(x):0.66 D(G(z)):0.27
# 이폭 [447/500] d_loss:1.0359 g_loss: 1.4293 D(x):0.67 D(G(z)):0.34
# 이폭 [448/500] d_loss:0.8840 g_loss: 1.5237 D(x):0.68 D(G(z)):0.28
# 이폭 [449/500] d_loss:0.9621 g_loss: 1.4474 D(x):0.67 D(G(z)):0.31
# 이폭 [450/500] d_loss:1.0116 g_loss: 1.5272 D(x):0.62 D(G(z)):0.29
# 이폭 [451/500] d_loss:0.8224 g_loss: 1.6439 D(x):0.75 D(G(z)):0.32
# 이폭 [452/500] d_loss:1.2769 g_loss: 1.4273 D(x):0.55 D(G(z)):0.32
# 이폭 [453/500] d_loss:1.1340 g_loss: 1.4964 D(x):0.63 D(G(z)):0.31
# 이폭 [454/500] d_loss:0.9256 g_loss: 1.4492 D(x):0.67 D(G(z)):0.31
# 이폭 [455/500] d_loss:0.8761 g_loss: 1.4666 D(x):0.70 D(G(z)):0.31
# 이폭 [456/500] d_loss:0.9097 g_loss: 1.2666 D(x):0.73 D(G(z)):0.35
# 이폭 [457/500] d_loss:0.8489 g_loss: 1.6012 D(x):0.69 D(G(z)):0.29
# 이폭 [458/500] d_loss:1.1029 g_loss: 1.4266 D(x):0.64 D(G(z)):0.32
# 이폭 [459/500] d_loss:1.1188 g_loss: 1.3856 D(x):0.61 D(G(z)):0.35
# 이폭 [460/500] d_loss:0.9424 g_loss: 1.6515 D(x):0.66 D(G(z)):0.27
# 이폭 [461/500] d_loss:0.9734 g_loss: 1.5926 D(x):0.69 D(G(z)):0.30
# 이폭 [462/500] d_loss:1.1424 g_loss: 1.1859 D(x):0.67 D(G(z)):0.40
# 이폭 [463/500] d_loss:1.0026 g_loss: 1.5769 D(x):0.63 D(G(z)):0.29
# 이폭 [464/500] d_loss:0.9294 g_loss: 1.3792 D(x):0.73 D(G(z)):0.35
# 이폭 [465/500] d_loss:1.1355 g_loss: 1.3248 D(x):0.67 D(G(z)):0.38
# 이폭 [466/500] d_loss:1.0301 g_loss: 1.2281 D(x):0.66 D(G(z)):0.38
# 이폭 [467/500] d_loss:0.9995 g_loss: 1.4244 D(x):0.65 D(G(z)):0.32
# 이폭 [468/500] d_loss:0.9931 g_loss: 1.1661 D(x):0.72 D(G(z)):0.39
# 이폭 [469/500] d_loss:0.9276 g_loss: 1.6361 D(x):0.65 D(G(z)):0.28
# 이폭 [470/500] d_loss:1.0399 g_loss: 1.5016 D(x):0.66 D(G(z)):0.33
# 이폭 [471/500] d_loss:1.0557 g_loss: 1.2690 D(x):0.71 D(G(z)):0.39
# 이폭 [472/500] d_loss:1.0078 g_loss: 1.3034 D(x):0.70 D(G(z)):0.36
# 이폭 [473/500] d_loss:0.8848 g_loss: 1.5441 D(x):0.69 D(G(z)):0.30
# 이폭 [474/500] d_loss:1.1193 g_loss: 1.3618 D(x):0.63 D(G(z)):0.35
# 이폭 [475/500] d_loss:0.8731 g_loss: 1.7708 D(x):0.68 D(G(z)):0.26
# 이폭 [476/500] d_loss:0.8875 g_loss: 1.6507 D(x):0.65 D(G(z)):0.25
# 이폭 [477/500] d_loss:0.9862 g_loss: 1.4679 D(x):0.65 D(G(z)):0.30
# 이폭 [478/500] d_loss:0.8506 g_loss: 1.4559 D(x):0.70 D(G(z)):0.30
# 이폭 [479/500] d_loss:1.0618 g_loss: 1.2830 D(x):0.64 D(G(z)):0.33
# 이폭 [480/500] d_loss:1.0999 g_loss: 1.4180 D(x):0.64 D(G(z)):0.34
# 이폭 [481/500] d_loss:0.9941 g_loss: 1.4061 D(x):0.65 D(G(z)):0.32
# 이폭 [482/500] d_loss:0.9603 g_loss: 1.3855 D(x):0.69 D(G(z)):0.34
# 이폭 [483/500] d_loss:0.9684 g_loss: 1.3435 D(x):0.71 D(G(z)):0.37
# 이폭 [484/500] d_loss:1.1031 g_loss: 1.3215 D(x):0.65 D(G(z)):0.35
# 이폭 [485/500] d_loss:0.7189 g_loss: 1.7753 D(x):0.72 D(G(z)):0.23
# 이폭 [486/500] d_loss:0.8763 g_loss: 1.5669 D(x):0.67 D(G(z)):0.27
# 이폭 [487/500] d_loss:1.0733 g_loss: 1.3049 D(x):0.67 D(G(z)):0.39
# 이폭 [488/500] d_loss:0.9293 g_loss: 1.4647 D(x):0.69 D(G(z)):0.30
# 이폭 [489/500] d_loss:0.9384 g_loss: 1.3914 D(x):0.69 D(G(z)):0.34
# 이폭 [490/500] d_loss:0.9563 g_loss: 1.2561 D(x):0.72 D(G(z)):0.38
# 이폭 [491/500] d_loss:1.0662 g_loss: 1.2877 D(x):0.67 D(G(z)):0.37
# 이폭 [492/500] d_loss:0.8928 g_loss: 1.3886 D(x):0.72 D(G(z)):0.34
# 이폭 [493/500] d_loss:1.0841 g_loss: 1.3352 D(x):0.64 D(G(z)):0.34
# 이폭 [494/500] d_loss:0.8546 g_loss: 1.7245 D(x):0.67 D(G(z)):0.26
# 이폭 [495/500] d_loss:1.0911 g_loss: 1.3331 D(x):0.69 D(G(z)):0.36
# 이폭 [496/500] d_loss:0.8743 g_loss: 1.5416 D(x):0.69 D(G(z)):0.29
# 이폭 [497/500] d_loss:0.9095 g_loss: 1.3955 D(x):0.69 D(G(z)):0.33
# 이폭 [498/500] d_loss:1.0579 g_loss: 1.4034 D(x):0.64 D(G(z)):0.33
# 이폭 [499/500] d_loss:0.9129 g_loss: 1.4654 D(x):0.71 D(G(z)):0.32

# %% [markdown]
# #### 9.2.4 결과물 시각화

# %%
# 생성자가 만든 이미지 시각화하기
z = torch.randn(BATCH_SIZE, 64).to(DEVICE)
fake_images = G(z)
for i in range(10):
    fake_images_img = np.reshape(fake_images.data.cpu().numpy()[i], (28, 28))
    
    plt.imshow(fake_images_img, cmap='gray')
    plt.show()
