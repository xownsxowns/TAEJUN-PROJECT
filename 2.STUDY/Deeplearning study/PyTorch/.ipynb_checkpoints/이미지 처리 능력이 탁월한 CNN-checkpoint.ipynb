# %% [markdown]
# ### 5.2 CNN 모델 구현하기

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

# %%
EPOCHS     = 40
BATCH_SIZE = 64

# %%
train_loader = torch.utils.data.DataLoader(
datasets.FashionMNIST('./ .data',
                    train = True,
                    download = True,
                    transform = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
batch_size = BATCH_SIZE, shuffle = True)

test_loader = torch.utils.data.DataLoader(
datasets.FashionMNIST('./ .data',
                     train = False,
                     transform = transforms.Compose([
                         transforms.ToTensor(),
                         transforms.Normalize((0.1307,), (0.3081,))
                     ])),
batch_size = BATCH_SIZE, shuffle = True)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size = 5) # 10개의 특징 맵을 생성
        self.conv2 = nn.Conv2d(10, 20, kernel_size = 5)
        self.drop  = nn.Dropout2d()
        self.fc1   = nn.Linear(320, 50)
        self.fc2   = nn.Linear(50, 10)
    
    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320) # view() 함수를 이용하여 1차원으로 펴주도록 함
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
model = CNN().to(DEVICE)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss   = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss:{:.6f}'.format(epoch, batch_idx * len(data),
                                                                         len(train_loader.dataset),
                                                                         100.*batch_idx/len(train_loader),
                                                                         loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            # 배치 오차를 합산
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            
            # 가장 높은 값을 가진 인덱스가 바로 예측값
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, epoch)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss:0.633501
# Train Epoch: 1 [12800/60000 (21%)]	Loss:0.560006
# Train Epoch: 1 [25600/60000 (43%)]	Loss:0.594356
# Train Epoch: 1 [38400/60000 (64%)]	Loss:0.967627
# Train Epoch: 1 [51200/60000 (85%)]	Loss:0.504870
# [1] Test Loss: 0.5444, Accuracy: 79.57%
# Train Epoch: 2 [0/60000 (0%)]	Loss:0.738389
# Train Epoch: 2 [12800/60000 (21%)]	Loss:0.491008
# Train Epoch: 2 [25600/60000 (43%)]	Loss:0.701662
# Train Epoch: 2 [38400/60000 (64%)]	Loss:0.690989
# Train Epoch: 2 [51200/60000 (85%)]	Loss:0.524783
# [2] Test Loss: 0.5071, Accuracy: 80.60%
# Train Epoch: 3 [0/60000 (0%)]	Loss:0.688152
# Train Epoch: 3 [12800/60000 (21%)]	Loss:0.501281
# Train Epoch: 3 [25600/60000 (43%)]	Loss:0.387270
# Train Epoch: 3 [38400/60000 (64%)]	Loss:0.765252
# Train Epoch: 3 [51200/60000 (85%)]	Loss:0.824189
# [3] Test Loss: 0.4655, Accuracy: 82.61%
# Train Epoch: 4 [0/60000 (0%)]	Loss:0.440198
# Train Epoch: 4 [12800/60000 (21%)]	Loss:0.426190
# Train Epoch: 4 [25600/60000 (43%)]	Loss:0.601411
# Train Epoch: 4 [38400/60000 (64%)]	Loss:0.592613
# Train Epoch: 4 [51200/60000 (85%)]	Loss:0.508962
# [4] Test Loss: 0.4294, Accuracy: 84.54%
# Train Epoch: 5 [0/60000 (0%)]	Loss:0.724740
# Train Epoch: 5 [12800/60000 (21%)]	Loss:0.530324
# Train Epoch: 5 [25600/60000 (43%)]	Loss:0.408361
# Train Epoch: 5 [38400/60000 (64%)]	Loss:0.336873
# Train Epoch: 5 [51200/60000 (85%)]	Loss:0.382758
# [5] Test Loss: 0.4097, Accuracy: 85.00%
# Train Epoch: 6 [0/60000 (0%)]	Loss:0.379609
# Train Epoch: 6 [12800/60000 (21%)]	Loss:0.429475
# Train Epoch: 6 [25600/60000 (43%)]	Loss:0.400783
# Train Epoch: 6 [38400/60000 (64%)]	Loss:0.388001
# Train Epoch: 6 [51200/60000 (85%)]	Loss:0.603479
# [6] Test Loss: 0.3966, Accuracy: 85.42%
# Train Epoch: 7 [0/60000 (0%)]	Loss:0.658605
# Train Epoch: 7 [12800/60000 (21%)]	Loss:0.486202
# Train Epoch: 7 [25600/60000 (43%)]	Loss:0.480198
# Train Epoch: 7 [38400/60000 (64%)]	Loss:0.471163
# Train Epoch: 7 [51200/60000 (85%)]	Loss:0.282408
# [7] Test Loss: 0.3700, Accuracy: 86.36%
# Train Epoch: 8 [0/60000 (0%)]	Loss:0.540752
# Train Epoch: 8 [12800/60000 (21%)]	Loss:0.388141
# Train Epoch: 8 [25600/60000 (43%)]	Loss:0.558114
# Train Epoch: 8 [38400/60000 (64%)]	Loss:0.373406
# Train Epoch: 8 [51200/60000 (85%)]	Loss:0.300838
# [8] Test Loss: 0.3636, Accuracy: 86.82%
# Train Epoch: 9 [0/60000 (0%)]	Loss:0.506330
# Train Epoch: 9 [12800/60000 (21%)]	Loss:0.344827
# Train Epoch: 9 [25600/60000 (43%)]	Loss:0.351243
# Train Epoch: 9 [38400/60000 (64%)]	Loss:0.288709
# Train Epoch: 9 [51200/60000 (85%)]	Loss:0.532225
# [9] Test Loss: 0.3574, Accuracy: 86.53%
# Train Epoch: 10 [0/60000 (0%)]	Loss:0.394891
# Train Epoch: 10 [12800/60000 (21%)]	Loss:0.483873
# Train Epoch: 10 [25600/60000 (43%)]	Loss:0.308562
# Train Epoch: 10 [38400/60000 (64%)]	Loss:0.406361
# Train Epoch: 10 [51200/60000 (85%)]	Loss:0.217887
# [10] Test Loss: 0.3586, Accuracy: 86.50%
# Train Epoch: 11 [0/60000 (0%)]	Loss:0.203067
# Train Epoch: 11 [12800/60000 (21%)]	Loss:0.401573
# Train Epoch: 11 [25600/60000 (43%)]	Loss:0.306959
# Train Epoch: 11 [38400/60000 (64%)]	Loss:0.230915
# Train Epoch: 11 [51200/60000 (85%)]	Loss:0.289035
# [11] Test Loss: 0.3364, Accuracy: 87.50%
# Train Epoch: 12 [0/60000 (0%)]	Loss:0.399850
# Train Epoch: 12 [12800/60000 (21%)]	Loss:0.359451
# Train Epoch: 12 [25600/60000 (43%)]	Loss:0.313052
# Train Epoch: 12 [38400/60000 (64%)]	Loss:0.270557
# Train Epoch: 12 [51200/60000 (85%)]	Loss:0.356921
# [12] Test Loss: 0.3346, Accuracy: 87.64%
# Train Epoch: 13 [0/60000 (0%)]	Loss:0.490264
# Train Epoch: 13 [12800/60000 (21%)]	Loss:0.355896
# Train Epoch: 13 [25600/60000 (43%)]	Loss:0.308890
# Train Epoch: 13 [38400/60000 (64%)]	Loss:0.456058
# Train Epoch: 13 [51200/60000 (85%)]	Loss:0.539090
# [13] Test Loss: 0.3248, Accuracy: 87.97%
# Train Epoch: 14 [0/60000 (0%)]	Loss:0.328040
# Train Epoch: 14 [12800/60000 (21%)]	Loss:0.345353
# Train Epoch: 14 [25600/60000 (43%)]	Loss:0.342038
# Train Epoch: 14 [38400/60000 (64%)]	Loss:0.478366
# Train Epoch: 14 [51200/60000 (85%)]	Loss:0.338048
# [14] Test Loss: 0.3261, Accuracy: 88.24%
# Train Epoch: 15 [0/60000 (0%)]	Loss:0.322688
# Train Epoch: 15 [12800/60000 (21%)]	Loss:0.224812
# Train Epoch: 15 [25600/60000 (43%)]	Loss:0.470934
# Train Epoch: 15 [38400/60000 (64%)]	Loss:0.484401
# Train Epoch: 15 [51200/60000 (85%)]	Loss:0.427326
# [15] Test Loss: 0.3178, Accuracy: 88.14%
# Train Epoch: 16 [0/60000 (0%)]	Loss:0.286712
# Train Epoch: 16 [12800/60000 (21%)]	Loss:0.269479
# Train Epoch: 16 [25600/60000 (43%)]	Loss:0.327532
# Train Epoch: 16 [38400/60000 (64%)]	Loss:0.218417
# Train Epoch: 16 [51200/60000 (85%)]	Loss:0.350271
# [16] Test Loss: 0.3123, Accuracy: 88.55%
# Train Epoch: 17 [0/60000 (0%)]	Loss:0.305231
# Train Epoch: 17 [12800/60000 (21%)]	Loss:0.332352
# Train Epoch: 17 [25600/60000 (43%)]	Loss:0.379515
# Train Epoch: 17 [38400/60000 (64%)]	Loss:0.366747
# Train Epoch: 17 [51200/60000 (85%)]	Loss:0.172478
# [17] Test Loss: 0.3241, Accuracy: 87.97%
# Train Epoch: 18 [0/60000 (0%)]	Loss:0.260243
# Train Epoch: 18 [12800/60000 (21%)]	Loss:0.262480
# Train Epoch: 18 [25600/60000 (43%)]	Loss:0.365954
# Train Epoch: 18 [38400/60000 (64%)]	Loss:0.370210
# Train Epoch: 18 [51200/60000 (85%)]	Loss:0.363762
# [18] Test Loss: 0.3274, Accuracy: 88.43%
# Train Epoch: 19 [0/60000 (0%)]	Loss:0.212238
# Train Epoch: 19 [12800/60000 (21%)]	Loss:0.288885
# Train Epoch: 19 [25600/60000 (43%)]	Loss:0.251867
# Train Epoch: 19 [38400/60000 (64%)]	Loss:0.335091
# Train Epoch: 19 [51200/60000 (85%)]	Loss:0.534741
# [19] Test Loss: 0.3133, Accuracy: 88.62%
# Train Epoch: 20 [0/60000 (0%)]	Loss:0.459134
# Train Epoch: 20 [12800/60000 (21%)]	Loss:0.292266
# Train Epoch: 20 [25600/60000 (43%)]	Loss:0.368748
# Train Epoch: 20 [38400/60000 (64%)]	Loss:0.444229
# Train Epoch: 20 [51200/60000 (85%)]	Loss:0.251499
# [20] Test Loss: 0.3055, Accuracy: 88.94%
# Train Epoch: 21 [0/60000 (0%)]	Loss:0.662427
# Train Epoch: 21 [12800/60000 (21%)]	Loss:0.216814
# Train Epoch: 21 [25600/60000 (43%)]	Loss:0.208424
# Train Epoch: 21 [38400/60000 (64%)]	Loss:0.253569
# Train Epoch: 21 [51200/60000 (85%)]	Loss:0.373299
# [21] Test Loss: 0.3074, Accuracy: 88.62%
# Train Epoch: 22 [0/60000 (0%)]	Loss:0.612402
# Train Epoch: 22 [12800/60000 (21%)]	Loss:0.270017
# Train Epoch: 22 [25600/60000 (43%)]	Loss:0.248697
# Train Epoch: 22 [38400/60000 (64%)]	Loss:0.572376
# Train Epoch: 22 [51200/60000 (85%)]	Loss:0.157515
# [22] Test Loss: 0.3046, Accuracy: 88.83%
# Train Epoch: 23 [0/60000 (0%)]	Loss:0.227057
# Train Epoch: 23 [12800/60000 (21%)]	Loss:0.523782
# Train Epoch: 23 [25600/60000 (43%)]	Loss:0.333928
# Train Epoch: 23 [38400/60000 (64%)]	Loss:0.291200
# Train Epoch: 23 [51200/60000 (85%)]	Loss:0.330855
# [23] Test Loss: 0.3022, Accuracy: 89.22%
# Train Epoch: 24 [0/60000 (0%)]	Loss:0.324662
# Train Epoch: 24 [12800/60000 (21%)]	Loss:0.233342
# Train Epoch: 24 [25600/60000 (43%)]	Loss:0.270487
# Train Epoch: 24 [38400/60000 (64%)]	Loss:0.174854
# Train Epoch: 24 [51200/60000 (85%)]	Loss:0.454523
# [24] Test Loss: 0.2991, Accuracy: 89.05%
# Train Epoch: 25 [0/60000 (0%)]	Loss:0.407763
# Train Epoch: 25 [12800/60000 (21%)]	Loss:0.335363
# Train Epoch: 25 [25600/60000 (43%)]	Loss:0.201068
# Train Epoch: 25 [38400/60000 (64%)]	Loss:0.372098
# Train Epoch: 25 [51200/60000 (85%)]	Loss:0.418785
# [25] Test Loss: 0.2991, Accuracy: 89.32%
# Train Epoch: 26 [0/60000 (0%)]	Loss:0.261949
# Train Epoch: 26 [12800/60000 (21%)]	Loss:0.346417
# Train Epoch: 26 [25600/60000 (43%)]	Loss:0.241364
# Train Epoch: 26 [38400/60000 (64%)]	Loss:0.244352
# Train Epoch: 26 [51200/60000 (85%)]	Loss:0.261634
# [26] Test Loss: 0.2947, Accuracy: 89.40%
# Train Epoch: 27 [0/60000 (0%)]	Loss:0.200266
# Train Epoch: 27 [12800/60000 (21%)]	Loss:0.451281
# Train Epoch: 27 [25600/60000 (43%)]	Loss:0.303545
# Train Epoch: 27 [38400/60000 (64%)]	Loss:0.198903
# Train Epoch: 27 [51200/60000 (85%)]	Loss:0.267923
# [27] Test Loss: 0.3023, Accuracy: 89.55%
# Train Epoch: 28 [0/60000 (0%)]	Loss:0.328486
# Train Epoch: 28 [12800/60000 (21%)]	Loss:0.291565
# Train Epoch: 28 [25600/60000 (43%)]	Loss:0.207968
# Train Epoch: 28 [38400/60000 (64%)]	Loss:0.336941
# Train Epoch: 28 [51200/60000 (85%)]	Loss:0.572643
# [28] Test Loss: 0.2988, Accuracy: 89.31%
# Train Epoch: 29 [0/60000 (0%)]	Loss:0.397189
# Train Epoch: 29 [12800/60000 (21%)]	Loss:0.234388
# Train Epoch: 29 [25600/60000 (43%)]	Loss:0.294604
# Train Epoch: 29 [38400/60000 (64%)]	Loss:0.280558
# Train Epoch: 29 [51200/60000 (85%)]	Loss:0.300926
# [29] Test Loss: 0.2997, Accuracy: 89.25%
# Train Epoch: 30 [0/60000 (0%)]	Loss:0.417238
# Train Epoch: 30 [12800/60000 (21%)]	Loss:0.349351
# Train Epoch: 30 [25600/60000 (43%)]	Loss:0.278037
# Train Epoch: 30 [38400/60000 (64%)]	Loss:0.173635
# Train Epoch: 30 [51200/60000 (85%)]	Loss:0.149926
# [30] Test Loss: 0.2899, Accuracy: 89.55%
# Train Epoch: 31 [0/60000 (0%)]	Loss:0.451504
# Train Epoch: 31 [12800/60000 (21%)]	Loss:0.258651
# Train Epoch: 31 [25600/60000 (43%)]	Loss:0.472559
# Train Epoch: 31 [38400/60000 (64%)]	Loss:0.362064
# Train Epoch: 31 [51200/60000 (85%)]	Loss:0.364409
# [31] Test Loss: 0.2999, Accuracy: 89.54%
# Train Epoch: 32 [0/60000 (0%)]	Loss:0.215452
# Train Epoch: 32 [12800/60000 (21%)]	Loss:0.185602
# Train Epoch: 32 [25600/60000 (43%)]	Loss:0.309737
# Train Epoch: 32 [38400/60000 (64%)]	Loss:0.267817
# Train Epoch: 32 [51200/60000 (85%)]	Loss:0.246772
# [32] Test Loss: 0.3025, Accuracy: 89.74%
# Train Epoch: 33 [0/60000 (0%)]	Loss:0.106727
# Train Epoch: 33 [12800/60000 (21%)]	Loss:0.184768
# Train Epoch: 33 [25600/60000 (43%)]	Loss:0.350641
# Train Epoch: 33 [38400/60000 (64%)]	Loss:0.341408
# Train Epoch: 33 [51200/60000 (85%)]	Loss:0.265974
# [33] Test Loss: 0.2899, Accuracy: 89.58%
# Train Epoch: 34 [0/60000 (0%)]	Loss:0.415177
# Train Epoch: 34 [12800/60000 (21%)]	Loss:0.334368
# Train Epoch: 34 [25600/60000 (43%)]	Loss:0.288751
# Train Epoch: 34 [38400/60000 (64%)]	Loss:0.383042
# Train Epoch: 34 [51200/60000 (85%)]	Loss:0.251338
# [34] Test Loss: 0.2980, Accuracy: 89.38%
# Train Epoch: 35 [0/60000 (0%)]	Loss:0.357474
# Train Epoch: 35 [12800/60000 (21%)]	Loss:0.340451
# Train Epoch: 35 [25600/60000 (43%)]	Loss:0.428523
# Train Epoch: 35 [38400/60000 (64%)]	Loss:0.377482
# Train Epoch: 35 [51200/60000 (85%)]	Loss:0.285588
# [35] Test Loss: 0.3005, Accuracy: 89.52%
# Train Epoch: 36 [0/60000 (0%)]	Loss:0.235955
# Train Epoch: 36 [12800/60000 (21%)]	Loss:0.290325
# Train Epoch: 36 [25600/60000 (43%)]	Loss:0.228450
# Train Epoch: 36 [38400/60000 (64%)]	Loss:0.133508
# Train Epoch: 36 [51200/60000 (85%)]	Loss:0.265642
# [36] Test Loss: 0.3078, Accuracy: 89.02%
# Train Epoch: 37 [0/60000 (0%)]	Loss:0.527708
# Train Epoch: 37 [12800/60000 (21%)]	Loss:0.391504
# Train Epoch: 37 [25600/60000 (43%)]	Loss:0.388440
# Train Epoch: 37 [38400/60000 (64%)]	Loss:0.406216
# Train Epoch: 37 [51200/60000 (85%)]	Loss:0.209090
# [37] Test Loss: 0.3008, Accuracy: 89.31%
# Train Epoch: 38 [0/60000 (0%)]	Loss:0.172910
# Train Epoch: 38 [12800/60000 (21%)]	Loss:0.503202
# Train Epoch: 38 [25600/60000 (43%)]	Loss:0.563851
# Train Epoch: 38 [38400/60000 (64%)]	Loss:0.436930
# Train Epoch: 38 [51200/60000 (85%)]	Loss:0.337225
# [38] Test Loss: 0.2961, Accuracy: 89.35%
# Train Epoch: 39 [0/60000 (0%)]	Loss:0.286681
# Train Epoch: 39 [12800/60000 (21%)]	Loss:0.156715
# Train Epoch: 39 [25600/60000 (43%)]	Loss:0.321029
# Train Epoch: 39 [38400/60000 (64%)]	Loss:0.136603
# Train Epoch: 39 [51200/60000 (85%)]	Loss:0.365054
# [39] Test Loss: 0.2881, Accuracy: 89.60%
# Train Epoch: 40 [0/60000 (0%)]	Loss:0.275114
# Train Epoch: 40 [12800/60000 (21%)]	Loss:0.190390
# Train Epoch: 40 [25600/60000 (43%)]	Loss:0.198316
# Train Epoch: 40 [38400/60000 (64%)]	Loss:0.290617
# Train Epoch: 40 [51200/60000 (85%)]	Loss:0.276384
# [40] Test Loss: 0.2937, Accuracy: 89.84%

# %% [markdown]
# ### 5.3 ResNet으로 컬러 데이터셋에 적용하기

# %%
EPOCHS = 300
BATCH_SIZE = 128

# %% [markdown]
# #### 5.3.2 CIFAR-10 데이터셋

# %%
train_loader = torch.utils.data.DataLoader(
datasets.CIFAR10('./ .data',
                train=True,
                download=True,
                transform=transforms.Compose([
                    transforms.RandomCrop(32, padding=4),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5),
                                        (0.5, 0.5, 0.5))])),
    batch_size=BATCH_SIZE, shuffle=True)

test_loader = torch.utils.data.DataLoader(
datasets.CIFAR10('./ .data',
                train=False,
                transform=transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5),
                                        (0.5, 0.5, 0.5))])),
    batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./ .data\cifar-10-python.tar.gz
# 14.5%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 40.3%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 62.1%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 85.5%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 100.0%
# Extracting ./ .data\cifar-10-python.tar.gz to ./ .data

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3,
                              stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                              stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        
        # ResNet의 두 번째 블록부터는 in_planes를 받아 self.bn2 계층의 출력 크기와 같은 planes와 더해주는 self.shortcut 모듈을 정의
        # nn.Sequential은 여러 모듈을 하나의 모듈로 묶는 역할을 한다.
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes))
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        # x를 self.shortcut을 거치게 하여 크기를 같게 하고 활서오하 함수를 거친 값에 더한다
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16
        
        self.conv1  = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1    = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(16, 2, stride=1)
        self.layer2 = self._make_layer(32, 2, stride=2)
        self.layer3 = self._make_layer(64, 2, stride=2)
        self.linear = nn.Linear(64, num_classes)
    
    def _make_layer(self, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(BasicBlock(self.in_planes, planes, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet().to(DEVICE)
optimzier = optim.SGD(model.parameters(), lr=0.1,
                     momentum=0.9, weight_decay=0.0005)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss   = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            # 배치 오차를 합산
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            
            # 가장 높은 값을 가진 인덱스가 바로 예측값
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    scheduler.step() # 학습률을 조금 낮춰주는 단계
    train(model, train_loader, optimizer, epoch)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch, test_loss, test_accuracy))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-21b08a895e2d> in <module>
#       1 for epoch in range(1, EPOCHS + 1):
#       2     scheduler.step() # 학습률을 조금 낮춰주는 단계
# ----> 3     train(model, train_loader, optimizer, epoch)
#       4     test_loss, test_accuracy = evaluate(model, test_loader)
#       5
#
# <ipython-input-29-a0dbff7f1705> in train(model, train_loader, optimizer, epoch)
#       6         output = model(data)
#       7         loss   = F.cross_entropy(output, target)
# ----> 8         loss.backward()
#       9         optimizer.step()
#      10
#
# c:\users\xowns\anaconda3\envs\tensorflow\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# c:\users\xowns\anaconda3\envs\tensorflow\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:
