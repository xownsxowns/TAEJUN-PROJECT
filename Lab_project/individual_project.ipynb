# %%
import pandas as pd
from antQuant.utils import DataManager

# %%
samsung = DataManager()
samsung_stock = samsung.get_daily_ohlcv('005930')
samsung_stock
# Out:
#                open     high      low    close  volume  adj_ratio
# date
# 1990-01-03    44000    45000    43200    44800   26240        1.0
# 1990-01-04    45000    45800    44800    45300   41900        1.0
# 1990-01-05    45000    45300    44300    44300   27400        1.0
# 1990-01-06    44800    45000    44500    44500   26380        1.0
# 1990-01-08    44500    44900    44000    44000   14790        1.0
# 1990-01-09    44500    44500    43500    44300   31250        1.0
# 1990-01-10    44300    44300    43800    43800   27820        1.0
# 1990-01-11    43800    43800    43200    43200   46610        1.0
# 1990-01-12    43300    43400    42900    43400   51580        1.0
# 1990-01-13    43200    43200    42900    43000   21860        1.0
# 1990-01-15    42700    42800    42200    42300   38330        1.0
# 1990-01-16    42300    42300    41400    42300   31830        1.0
# 1990-01-17    42200    42200    41800    41800   26060        1.0
# ...

# %%
samsung_stock.index.get_loc('2016-01-04')
# Out:
# 6845

# %%
samsung_stock = samsung_stock[samsung_stock.index.get_loc('2016-01-04'):]

# %%
samsung_stock
# Out:
#                open     high      low    close  volume  adj_ratio
# date
# 2016-01-04  1260000  1260000  1205000  1205000  306939        1.0
# 2016-01-05  1202000  1218000  1186000  1208000  216002        1.0
# 2016-01-06  1208000  1208000  1168000  1175000  366752        1.0
# 2016-01-07  1166000  1183000  1151000  1163000  282388        1.0
# 2016-01-08  1163000  1186000  1163000  1171000  257763        1.0
# 2016-01-11  1156000  1166000  1146000  1152000  241277        1.0
# 2016-01-12  1148000  1166000  1144000  1146000  206283        1.0
# 2016-01-13  1153000  1159000  1148000  1148000  143316        1.0
# 2016-01-14  1131000  1142000  1131000  1138000  209022        1.0
# 2016-01-15  1140000  1152000  1124000  1132000  209464        1.0
# 2016-01-18  1088000  1133000  1088000  1126000  320214        1.0
# 2016-01-19  1128000  1171000  1128000  1171000  207242        1.0
# 2016-01-20  1160000  1160000  1132000  1138000  167052        1.0
# ...

# %%
samsung = pd.read_excel('datalab_samsung.xlsx')
samsungbio = pd.read_excel('datalab_samsungbio.xlsx')
hynix = pd.read_excel('datalab_skhynix.xlsx')
celltrion = pd.read_excel('datalab_celltrion.xlsx')
hyundai = pd.read_excel('datalab_hyundai.xlsx')

# %%
samsung = samsung[6:]
samsungbio = samsungbio[6:]
hynix = hynix[6:]
celltrion = celltrion[6:]
hyundai = hyundai[6:]

# %%
samsung.columns = ['Date', 'Search_rate']

# %%
samsung = samsung.set_index('Date')

# %%
samsung
# Out:
#            Search_rate
# Date
# 2016-01-01     0.73146
# 2016-01-02     0.83392
# 2016-01-03     0.85521
# 2016-01-04      2.6586
# 2016-01-05     2.41191
# 2016-01-06     2.43516
# 2016-01-07      2.6519
# 2016-01-08     3.16608
# 2016-01-09      1.0146
# 2016-01-10     0.92072
# 2016-01-11     2.57405
# 2016-01-12     2.57575
# 2016-01-13     2.18325
# 2016-01-14     2.37161
# 2016-01-15     2.11601
# 2016-01-16     0.99687
# 2016-01-17     0.90277
# 2016-01-18     2.46596
# 2016-01-19     2.38081
# 2016-01-20     2.62331
# 2016-01-21     2.36605
# 2016-01-22     2.33712
# 2016-01-23      0.9967
# 2016-01-24     0.90218
# 2016-01-25     2.19899
# 2016-01-26     2.30628
# 2016-01-27     2.30793
# 2016-01-28     4.38461
# 2016-01-29     2.25439
# 2016-01-30     0.99101
# ...                ...
# 2018-03-02     4.95131
# 2018-03-03     1.53238
# 2018-03-04     1.50192
# 2018-03-05     5.55021
# 2018-03-06     5.68681
# 2018-03-07      6.3532
# 2018-03-08     5.88336
# ...
