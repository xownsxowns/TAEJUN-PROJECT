# %%
import pandas as pd
import statsmodels.formula.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn import preprocessing
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
chicken1 = pd.read_excel('data_chicken/data_1.xls',header=None)

# %%
chicken1
# Out:
#       0       1      2  3  4  5  6
# 0   280  208904    450  1  0  0  0
# 1   199  160021    130  1  0  0  0
# 2   160  125580    195  1  0  0  0
# 3   194  222652    375  1  0  0  0
# 4   231  230570    160  1  0  0  0
# 5   210  146196     40  1  0  0  0
# 6   212  156671    105  1  0  0  0
# 7   119   93402     70  1  0  0  0
# 8   241  204606    193  1  0  0  0
# 9   180  125384     70  1  0  0  0
# 10  143  145179    315  1  0  0  0
# 11  136  159770    100  1  0  0  0
# 12  160  153610    135  1  0  0  0
# 13  147  126581    145  1  0  0  0
# 14  189  155051    230  1  0  0  0
# 15  132  116401     95  1  0  0  0
# 16  209  174370    205  1  0  0  0
# 17  216  230801    321  1  0  0  0
# 18  141  163253    130  1  0  0  0
# 19  175  146904    215  1  0  0  0
# 20   96   90164    190  1  0  0  0
# 21  187  178775     40  1  0  0  0
# 22  137   60786    290  1  0  0  0
# 23  141   51503    475  1  0  0  0
# 24  172  157571     55  1  0  0  0
# 25  280  208904   6337  0  1  0  0
# ...

# %%
chicken1.columns = ["total_number", "house", "call", "morning", "lunch", "dinner","yasik"]

# %%
chicken1.min()
# Out:
# total_number       96
# house           51503
# call               40
# morning             0
# lunch               0
# dinner              0
# yasik               0
# dtype: int64

# %%
chicken1.max()
# Out:
# total_number       280
# house           230801
# call             33446
# morning              1
# lunch                1
# dinner               1
# yasik                1
# dtype: int64

# %%
chicken1
# Out:
#     total_number   house   call  morning  lunch  dinner  yasik
# 0            280  208904    450        1      0       0      0
# 1            199  160021    130        1      0       0      0
# 2            160  125580    195        1      0       0      0
# 3            194  222652    375        1      0       0      0
# 4            231  230570    160        1      0       0      0
# 5            210  146196     40        1      0       0      0
# 6            212  156671    105        1      0       0      0
# 7            119   93402     70        1      0       0      0
# 8            241  204606    193        1      0       0      0
# 9            180  125384     70        1      0       0      0
# 10           143  145179    315        1      0       0      0
# 11           136  159770    100        1      0       0      0
# 12           160  153610    135        1      0       0      0
# 13           147  126581    145        1      0       0      0
# ...

# %%
chicken1['call_for_onestore'] = chicken1['call']/chicken1['total_number']

# %%
chicken1
# Out:
#     total_number   house   call  morning  lunch  dinner  yasik  \
# 0            280  208904    450        1      0       0      0
# 1            199  160021    130        1      0       0      0
# 2            160  125580    195        1      0       0      0
# 3            194  222652    375        1      0       0      0
# 4            231  230570    160        1      0       0      0
# 5            210  146196     40        1      0       0      0
# 6            212  156671    105        1      0       0      0
# 7            119   93402     70        1      0       0      0
# 8            241  204606    193        1      0       0      0
# 9            180  125384     70        1      0       0      0
# 10           143  145179    315        1      0       0      0
# 11           136  159770    100        1      0       0      0
# 12           160  153610    135        1      0       0      0
# 13           147  126581    145        1      0       0      0
# ...

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x = chicken1['total_number'].values.astype(float)
x = x.reshape(-1,1)
x_scaled = min_max_scaler.fit_transform(x)
chicken1['total_number'] = pd.DataFrame(x_scaled)

# %%
x = chicken1['house'].values.astype(float)
x = x.reshape(-1,1)
x_scaled = min_max_scaler.fit_transform(x)
chicken1['house'] = pd.DataFrame(x_scaled)

# %%
chicken1.loc[chicken1['house'] == 1]
# Out:
#     total_number  house   call  morning  lunch  dinner  yasik  \
# 17      0.652174    1.0    321        1      0       0      0
# 42      0.652174    1.0   4709        0      1       0      0
# 67      0.652174    1.0  21466        0      0       1      0
# 92      0.652174    1.0   7424        0      0       0      1
#
#     call_for_onestore
# 17           1.486111
# 42          21.800926
# 67          99.379630
# 92          34.370370

# %%
a = 1
b = 0
c = 0
d = 0
e = 1
f = 0.652174

# %%
result = 23 + 22*a -25*b -9*c + 56*d +2*e -21*f

# %%
result
# Out:
# 33.304345999999995
